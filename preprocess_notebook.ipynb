# %% [markdown]
# # Preprocess Notebook
#
# This notebook is dedicated to the preprocessing of the data. The input file is in the format of an .tmx file. The steps that are currently being done are:
# 1. Extract lines
# 2. Store surplus
# 3. Pair lines
# 4. Clear punctuation
# 5. Sample the dataset
#
# ## Imports
# Below are all the libraries used for this notebook

# %%
import re
import pickle
import copy

import nltk

# %% [markdown]
# ## Cleaning the data
# This function includes all cleaning steps of the data. It reads the tmx file, takes out the lines that interest the model, removes unnecessary tags, and pairs the lines as englist-dutch respective order. Afterwards, it writes the data in a pickle for further usage. A pickle reading function with an optional limiter has also been included.

# %%
def clean(input_location: str, output_location: str, chunk_size = 1048576):
    """ This function takes a file, reads it, separates it, and saves it
    to a document via pickling it. Chunk size means the number of characters
    which roughly converts to the amount of bytes. Default setting is equal to a
    Megabyte. """
    
    # Opening the filestreams
    input_file = open(input_location, "r")
    output_file = open(f"data/{output_location}", "wb")
    
    # Reading the first chunk
    chunk = input_file.read(chunk_size)
    
    waiting_single = [[], []]              # Variable to hold the line pairs
    extra = " "                            # Variable to hold extra strings
    
    while chunk:
        #print(chunk+extra+"\n\n")
        lines, extra = getLines(extra + chunk)
        #print(f"{lines}\n{extra}")
        if not lines:
            chunk = input_file.read(chunk_size)
            continue
        waiting_single, pairs = pair(waiting_single, lines)
        pickle.dump(pairs, output_file)
        chunk = input_file.read(chunk_size)
    input_file.close()
    output_file.close()

# %%
def pair(temp: list, lines: list) -> list:
    """ Takes two list, one with all the unpaired lines, and a list with possibly an
    unpaired single and a tag. """
    
    results = list()
    for tag, line in lines:
        if len(temp[0]) == 2 and f"{temp[1][0]}{temp[1][1]}" != "ennl":
            # If the pair is wrongly ordered
            print(temp)
            print(results)
            raise Exception("Line mismatch occured")
        elif len(temp[0]) == 2:
            # If the pair is correct
            results.append(copy.copy(temp[0]))
            temp = [[],[]]
        # The part which adds a line to be paired
        temp[0].append(line)
        temp[1].append(tag)
    return (temp, results)

# %%
def getLines(temp_str: str) -> (list, str):
    """ Takes a string, extracts the lines with actual quotes.
    Returns the lines and the string left after the last line. """
    
    lines = re.findall(r"<tuv.+?(?=</seg>)</seg>", temp_str)
    # If there is no lines to find, pass the string as a whole
    if not lines:
        return [[], temp_str]
    # If there is a line, this part extracts the text after
    # the last scanned line
    if lines[-1] != temp_str[-len(lines[-1]):]:
        remnants = ""
        for i in range(1, len(temp_str)-len(lines[-1])):
            if lines[-1] == temp_str[-(len(lines[-1])+i):-i]:
                break
            else:
                remnants += temp_str[-i]
    # Erases the parts we are not interested in
    lines = [(line[15:17], line[24:-6]) for line in lines]
    return (lines, remnants[::-1])

# %% [markdown]
# ## Pickle Functions:

# %%
def readPickle(pickle_off: str, limiter = -1):
    """ Read the pickle either in a limited amount of chunks or all
    of them at once. """
    objects = []
    file_stream = open(pickle_off, "rb")
    while limiter != 0:
        try:
            objects.append(pickle.load(file_stream))
            limiter -= 1
        except EOFError:
            break
    file_stream.close()
    return objects

# %%
def processPickle(pickle_off: str, process=lambda x:x, limiter = -1, store=False):
    """ Takes in a pickle, reads it in chunks and applies the process function to it in each chunk.
    Depending on the store value, it either stores the results in a list and returns it or returns nothing.
    The process function can only have one input which is the read object from the pickle. """
    
    objects = []
    file_stream = open(pickle_off, "rb")
    
    while limiter != 0:
        try:
            if store:objects.append(process(pickle.load(file_stream)))
            else:process(pickle.load(file_stream))
            limiter -= 1
        except EOFError: # When there is nothing else to read
            break
    file_stream.close()
    if store: return objects

# %%
def getLen(lines: list)->int:
    """ Takes a list of lines, prints and returns the length. """
    l = len(lines)
    print(f"The length of this chunk is {l} lines")
    return l

# %%
# In order to get the full length of a pickle, we do
full_l = sum(processPickle("data/sample0.pkl",process = getLen, store = True))
print(f"The total length of pickle is {full_l} lines")
# Out:
# The length of this chunk is 83064 lines
# The length of this chunk is 75154 lines
# The length of this chunk is 77409 lines
# The length of this chunk is 95147 lines
# The length of this chunk is 84284 lines
# The length of this chunk is 81818 lines
# The length of this chunk is 74158 lines
# The length of this chunk is 71400 lines
# The length of this chunk is 75132 lines
# The length of this chunk is 77556 lines
# The length of this chunk is 49404 lines
# The total length of pickle is 844526 lines

# %% [markdown]
# ## Sampling

# %%
# The pattern to tokenize each sentence
pattern = r'''(?x)           # set flag to allow verbose regexps
     (?:[A-Z]\.)+            # abbreviations, e.g. U.S.A.
   | \w+(?:[-']\w+)*[,:;']?  # words with optional internal hyphens
'''

def cleanPunc(line: str) -> list:
    """ Takes a string, makes all of them lowercase and tokenizes it, getting rid of unwanted characters. """
    return nltk.regexp_tokenize(line.lower(), pattern)

def samplingDataset(line_pairs: list, sampleCheck) -> list:
    """ Takes a list of tokenized pairs, and a function to check one of the tokenized lists.
    Extracts the ones that return true for the check. """
    sample = list()
    for en, nl in line_pairs:
        temp_en = cleanPunc(en)
        temp_nl = cleanPunc(nl)
        if sampleCheck(temp_en):
            sample.append([" ".join(temp_en), " ".join(temp_nl)])
    return sample

def samplingMethod1(line: list) -> bool:
    """ Takes in a list of strings. Checks if it has the given words in given indexes depending on
    the list. """
    
    # This list is formed of lists of an index and the possible words that are supposed to be
    # in that index
    check_list = [[0, ["he", "she", "it"]], [1, ["is"]]]
    
    for index, words in check_list:
        if len(line) <= check_list[-1][0] or not line[index] in words:
            return False
    return True

def samplingMethod2(line: list) -> bool:
    """ Takes in a list of strings. Checks if it has the given words in given indexes depending on
    the list. """
    
    # This list is formed of lists of an index and the possible words that are supposed to be
    # in that index
    check_list = [[0, ["he", "she", "we", "i", "you"]], [1, ["is", "are", "am"]]]
    
    for index, words in check_list:
        length = len(line)
        if length > 10 or length <= check_list[-1][0] or not line[index] in words:
            return False
    return True

def pickleSample(output_location: str, sampleCheck=lambda x:True):
    """ Takes in an output location, and a function to apply sampling with. Uses the process pickle
    function to chunk the pickle and apply the sampling in each chunk. Then writes the cumulative
    result to a new pickle. """
    output_file = open(f"data/{output_location}", "wb")
    processPickle("data/en_nl_line_pairs.pkl",
                  process=lambda x:pickle.dump(samplingDataset(x, sampleCheck), output_file))

# %%
# Example usage
pickleSample("sample1.pkl", sampleCheck=samplingMethod2)

# %%
readPickle("data/sample1.pkl")
# Out:
# [[['we are standing on it', 'we staan erop'],
#   ['we are expecting to find water', 'dit hadden we niet verwacht'],
#   ['we are at the centre', 'en wij staan in het midden'],
#   ['you are exactly what i need', 'je bent precies wat ik nodig heb'],
#   ['i am sorry, noel', 'het spijt me, noel'],
#   ['you are a gem', 'je bent een juweeltje'],
#   ['you are very welcome, elizabeth', 'graag gedaan, elizabeth'],
#   ['i am trust me i am', 'kan ik aan, geloof me'],
#   ['we are louis and jessica huang we live in orlando',
#    'wij zijn louis en jessica huang, we wonen in orlando'],
#   ['i am the year of the dog', 'ik ben het jaar van de hond'],
#   ['we are all our own leaders', 'wij zijn allemaal onze eigen leiders'],
#   ['i am not a follower', 'volg mij ik ben geen volger'],
#   ['i am real hungry for bark', 'ik heb echt trek in schors'],
#   ['you are totally deflecting i am who i am', 'u dwaalt af'],
#   ['you are who you are', 'ik ben wie ik ben u bent wie u bent'],
#   ['we are so doing this', 'we gaan het doen'],
#   ['i am ahab', 'ik ben ahab'],
#   ['she is the one who should be in here', 'ze is degene die hier moet zijn'],
#   ['you are all useless', 'jullie zijn allemaal nutteloos'],
#   ['you are distracting the dogs, detective',
#    'u leidt de honden af, rechercheur'],
#   ['you are canadian after all', 'je bent canadees'],
#   ['she is of interest',
#    "terug op de schaats voor haar moeder's lichaam zelfs koud is"],
#   ['i am suggesting that you would do such a thing',
#    'miss howard, aangezien je degene bent die iets te winnen heeft,'],
#   ['you are a clever man', 'je bent een slimme man'],
#   ['we are going to pursue', 'we gaan streven'],
#   ['we are on roller skates', 'we rijden op rolschaatsen'],
#   ['i am ordering you to shoot', 'ik beveel je om te schieten'],
#   ['i am not', 'doe ik niet'],
#   ['we are not allowed to smoke', 'we mogen niet roken'],
#   ['we are approaching water world', 'we naderen waterworld'],
#   ['we are', 'doen we al'],
#   ['i am not here to hurt you, liz', 'ik wil je geen pijn doen, liz'],
#   ['he is not who you think he is', 'hij is niet wie je denkt dat hij is'],
#   ['i am evan baxter', 'ik ben evan baxter'],
#   ['i am successful and happy, powerful',
#    'ik ben succesvol, invloedrijk, knap en gelukkig'],
#   ['i am the one that has to read it', 'ik ben diegene die dit moet lezen'],
#   ['i am a congress member', 'ik ben een united states congreslid'],
#   ['i am busy, i like in seeing you',
#    'druk, druk, druk leuk u te hebben gezien'],
#   ['you are entitled all to get scared',
#    'schatje, je hebt alle recht om door te draaien'],
#   ['i am building something', 'ik ben iets aan het bouwen'],
#   ['i am with the flock',
#    'doe je met de groep mee of doe je het alleen ik ben een groepsman'],
#   ['i am building an ark', 'ik bouw een ark'],
#   ['you are grandiose',
#    'goed jullie te zien jongens het is goed om jou te zien'],
#   ['i am suspended but i continue being a congress member',
#    'hij kan dat niet doen ik ben geschorst maar nog steeds congreslid'],
#   ['i am suspended', 'wat kunnen we doen'],
#   ['i am cold and wet and i leave home',
#    'daar ben ik het ook mee eens ik ben koud, nat en ga naar huis'],
#   ['i am calling you', 'ik roep je'],
#   ['you are dr caligari', 'u bent dr caligari'],
#   ['he is caligari', 'hij is caligari'],
#   ['she is as tender as tuscan veal', 'echt een mals lapje'],
#   ['he is alive', 'hij leeft'],
#   ["i am going to my husband's father", 'ik ga naar de vader van paul'],
#   ['he is rich he can help if he will',
#    'hij is rijk hij kan helpen als hij wil ga daar niet naartoe'],
#   ['i am vasseur, who was executed on july 13th',
#    'ik ben vasseur, terechtgesteld op 13 juli'],
#   ['you are', 'u paul orlac'],
#   ['i am also a blackmailer', 'ik ben dus een afperser'],
#   ["he is sending for the world's greatest detective, sherlock jr",
#    'we zijn verloren hij haalt de beste detective ter wereld erbij:'],
#   ['we are lost', 'geloof noch kennis'],
#   ['you are the master, and i am your servant',
#    'jij bent de meester, en ik ben jouw knecht'],
#   ['he is in league with the devil',
#    'hij heeft een pact gesloten met de duivel'],
#   ['i am too old', 'lk ben te oud'],
#   ['i am enslaved for eternity', 'je behoort mij nu voor eeuwig toe'],
#   ['she is not for you', 'dat is niets voor jou'],
#   ['i am yours forever', 'lk ben voor eeuwig de jouwe'],
#   ['you are still my servant', 'je bent nog steeds mijn knecht'],
#   ['he is more valuable to the south as an engineer',
#    'hij is nuttiger voor het zuiden als machinist'],
#   ['i am not your father', 'ik ben je vader niet'],
#   ['i am shunsaku ban, a private detective from japan',
#    'ik ben shunsaku ban, een privé-detective uit japan'],
#   ['i am model 803-d, rp, dm, 497-3c', 'ik ben model 803-d, r-p, dm, 497-3c'],
#   ['we are not given names like people',
#    'we krijgen geen namen, zoals mensen'],
#   ['she is the greatest work of my life', "ze is m'n grootste levenswerk"],
#   ["i am working on tima at duke red's request",
#    'ik werk aan tima op verzoek van duke red'],
#   ['i am', 'ik ben'],
#   ['you are i', 'jij bent ik'],
#   ['you are i i am you wait', "jij bent ik' ik ben jij' wacht"],
#   ['i am sorry for not being more helpful',
#    'het spijt me dat ik niet van meer nut kon zijn'],
#   ['i am a fair man', 'ik ben een eerlijk man'],
#   ['you are no mere human', 'je bent geen gewoon mens'],
#   ['you are a superhuman', 'jij bent een supermens'],
#   ['you are the greatest, most sublime creation ever',
#    'je bent de grootste en meest sublieme schepping aller tijden'],
#   ['you are still not complete', 'je bent nog niet voltooid'],
#   ['i am an artificial human', 'ik ben een kunstmatig mens'],
#   ['she is natalie dabrova, the most dangerous revolutionist in russia',
#    'zij is natalie dabrova, de gevaarlijkste revolutionaire in rusland'],
#   ['you are very beautiful', 'je bent zo mooi'],
#   ['you are the general in command', 'jij bent de generaal van dienst'],
#   ['i am death', 'ik ben de dood'],
#   ['you are frightened', 'je bent bang'],
#   ['you are awful', 'je bent onuitstaanbaar'],
#   ['i am looking', 'ik kijk'],
#   ['he is a desperate character', 'hij is een hopeloos figuur'],
#   ['we are now back in the studio', 'we zijn terug in de studio'],
#   ['we are all looking for love sofiya magarill',
#    'we zijn allemaal op zoek naar liefde sofia magarill'],
#   ['we are all looking for love', 'we zijn allemaal op zoek naar liefde'],
#   ['i am looking for love, mademoiselle',
#    'ik ben op zoek naar liefde, mademoiselle'],
#   ['we are not french', 'we zijn geen fransen'],
#   ['we are communards', 'wij zijn lid van de commune'],
#   ['you are the life of the fatherland, you boys',
#    'het lot van het vaderland ligt in jullie handen'],
#   ['you are the iron men of germany',
#    'jullie zijn de ijzervreters van duitsland'],
#   ['we are in no mood for recreation', 'geen zin in ontspanning'],
#   ['you are a very beautiful woman', 'u bent een heel mooie vrouw'],
#   ['he is the only white man to cover every acre',
#    'hij is de enige blanke die daar elk plekje kent'],
#   ['i am emanuel ravelli', 'ik ben emanuel ravelli'],
#   ['you are one of the musicians', 'bent u een van de musici'],
#   ['i am one of the most well-known men in america',
#    'ik ben een van de bekendste mannen van amerika'],
#   ['you are wrong i told you before',
#    'u vergist zich, dat heb ik u toch gezegd'],
#   ["you are right it's not the beaugard", 'klopt, het is niet van beaugard'],
#   ['i am lord leopold plumtree', 'ik ben lord leopold plumtree'],
#   ['i am sitting on my mule', "ik zit op m'n ezel"],
#   ['i am mrs tanner', 'ik ben mrs tanner'],
#   ['you are a clever woman, and a very loyal one',
#    'u bent een slimme vrouw, en heel loyaal'],
#   ['you are wanted on the telephone, sir', 'er is telefoon voor u, meneer'],
#   ['i am sorry, sir', 'het spijt me'],
#   ['i am certain it is', 'dat geloof ik graag'],
#   ['i am going after the other man', 'ik ga achter de andere man aan'],
#   ['you are so powerful', 'je bent zo sterk'],
#   ['i am glad you escaped', 'ik ben blij dat je ontsnapt bent'],
#   ['you are still a clown', 'je blijft een clown'],
#   ['i am going to face this journey, too, alone',
#    'deze reis maak ik ook alleen'],
#   ['i am here to help you', 'ik ben hier om u te helpen'],
#   ['we are ready for him', 'we zijn klaar voor hem'],
#   ['she is not here', 'ze is er niet'],
#   ['we are about to unfold the story of frankenstein',
#    'zo dadelijk volgt het verhaal van frankenstein'],
#   ['i am dr waldman', 'pardon ik ben dr waldman'],
#   ['you are crazy, you dirty swine', 'je bent gek, jij, smerig zwijn'],
#   ['we are all law experts here',
#    'we zijn hier allemaal experts op het gebied van rechten'],
#   ['he is right', 'hij heeft gelijk'],
#   ['he is mistaken', 'hij heeft het fout'],
#   ['he is not', 'niet waar'],
#   ['you are different, tommy', 'je bent anders, tommy'],
#   ['i am no gentleman, no, but i have money',
#    'ik ben geen heer, nee, maar ik heb geld'],
#   ['i am no beauty', 'ik ben geen schoonheid'],
#   ['you are pleased', 'je vindt het fijn'],
#   ['you are good, you are', 'u bent echt goed'],
#   ['i am damned', 'ik ben verdoemd'],
#   ['you are a poor man', 'u bent straatarm'],
#   ['i am in my right mind', 'natuurlijk ben ik helder'],
#   ['he is dissatisfied with room 559', 'hij is niet tevreden over kamer 559'],
#   ['he is at the end of the corridor', 'hij woont achteraan in de gang lang'],
#   ['i am felix benvenuto frihern von geigern',
#    'ik ben felix benvenuto frihern von geigern'],
#   ['i am away, sick', 'ik ben met ziekteverlof'],
#   ['you are annoying', 'u bent lastig'],
#   ['you are probably an embezzler', 'u bent vast een verduisteraar'],
#   ['you are going to take that back', 'dat zult u terug nemen'],
#   ["you are very slender, aren't you", 'je bent heel slank, hé'],
#   ['you are all familiar with the symptoms of cirrhosis',
#    'jullie weten allemaal wat cirrose is'],
#   ['you are fooling around with her', 'je rommelt met haar'],
#   ['i am addressing sir joseph whemple yes',
#    'spreek ik hier met sir joseph whemple'],
#   ['i am ardath bey', 'ik ben ardath bey'],
#   ['i am ardath bey', 'mijn naam is ardath bey'],
#   ['i am helen grosvenor', 'ik ben helen grosvenor'],
#   ['i am so glad you understand', 'u begrijpt het'],
#   ['i am anck-es-en-amon, but i', 'ik ben anckh-es-en-amon, maar ik'],
#   ['i am rather a nervous man', 'ik ben nogal een nerveuze man'],
#   ['he is indeed', 'inderdaad'],
#   ['we are all touched with it a little, you see',
#    'we zijn er allemaal een beetje door geraakt, zie je'],
#   ['i am damned', 'ik ben verdoemd'],
#   ['you are expected, dr bruner', 'u wordt verwacht, dr bruner'],
#   ['she is deep in love', 'ze is heel erg verliefd'],
#   ["i am not i've got friends among the natives",
#    'ik niet, ik heb vrienden onder de inheemse bevolking'],
#   ["you are a doctor, aren't you", 'u bent toch dokter'],
#   ['you are a man of discretion, mr parker',
#    'u bent een discrete man, meneer parker'],
#   ['she is human', 'ze is menselijk'],
#   ['he is man like him', 'een man zoals hij'],
#   ['i am the state', 'hij erkent alleen zijn eigen autoriteit'],
#   ['i am shut up', "ik hou m'n kop"],
#   ['you are cordially invited to attend my teaparty',
#    'u bent van harte welkom op mijn theepartij'],
#   ['he is on a friendly visit', 'hij is hier met goede bedoelingen'],
#   ['i am a little headstrong i come by it honestly',
#    'misschien heb ik een wat harde kop, dat zit in de familie'],
#   ['we are so accustomed to watching our feet',
#    'je bent gewend om naar je voeten te kijken'],
#   ['he is making for the empire state building',
#    'hij gaat naar het empire state building'],
#   ['he is still carrying ann darrow', 'hij draagt nog steeds ann darrow'],
#   ['he is a very stubborn person, i assure you',
#    'hij is een zeer koppig persoon, dat kan ik u verzekeren'],
#   ['you are very gracious', 'u bent erg vriendelijk'],
#   ['you are very kind, sir', 'u bent erg aardig, meneer'],
#   ['you are asking to destroy all', 'u vraagt om te vernietigen'],
#   ['you are insane', 'u bent gestoord'],
#   ['i am right', 'ik heb gelijk'],
#   ['you are very generous, mr igor', 'u bent erg gul, meneer igor'],
#   ['i am going to give you immortality', 'ik ga je onsterfelijkheid geven'],
#   ['you are crazy', 'u bent gek'],
#   ['i am nice', 'ik ben aardig'],
#   ['we are', 'dat zijn we ook'],
#   ["you are upset, aren't you", 'je bent toch van slag'],
#   ['we are all very fortunate to be alive',
#    'we hadden allemaal veel geluk het er levend vanaf te brengen'],
#   ['he is perhaps sentimental about this spot',
#    'hij is misschien sentimenteel over deze plek'],
#   ['you are frightened, doctor', 'u bent bang, dokter'],
#   ['you are our host', 'u bent onze gastheer'],
#   ['he is quite right you had a severe shock',
#    'hij heeft gelijk, je had een zware shock'],
#   ['you are the very core and meaning of my life',
#    'je bent de kern en de betekenis van mijn leven'],
#   ['he is not in his room', 'hij is niet in zijn kamer'],
#   ['he is perhaps at breakfast', 'hij is misschien wel aan het ontbijten'],
#   ['you are interested', 'je bent geïnteresseerd'],
#   ['i am karen, madame poelzig', 'ik ben karen, madame poelzig'],
#   ['she is alive, here in this house', 'ze leeft, hier in dit huis'],
#   ["she is poelzig's wife", "ze is poelzig's vrouw"],
#   ['he is with mr wang, sir yeah', 'hij is bij mr wang, meneer'],
#   ['i am happy you like it', 'ik ben blij dat u het lekker vindt'],
#   ['i am told you have arrived at a conclusion, caesar',
#    'ik heb gehoord dat u een besluit hebt genomen, caesar'],
#   ['i am cleopatra', 'ik ben cleopatra'],
#   ['she is cleopatra, and i am caesar', 'zij is cleopatra, en ik ben caesar'],
#   ['i am here to make you very happy',
#    'ik ben hier om je heel gelukkig te maken'],
#   ['she is', 'echt mooi'],
#   ['i am only a man', 'ik ben maar een man'],
#   ['you are a good fisherman', 'je bent een goede visser'],
#   ['i am strong, majesty', 'ik ben sterk, majesteit'],
#   ['we are romans', 'wij zijn romeinen'],
#   ['i am blind indeed', 'ik ben inderdaad blind'],
#   ['i am dying, egypt', 'ik sterf, egypte'],
#   ['i am taking you with me, egypt', 'ik neem je mee, egypte'],
#   ['i am taking you with me', 'ik neem je mee'],
#   ['i am', 'met mij'],
#   ['he is running away', 'hij loopt weg'],
#   ['we are gonna put the bite on sorrowful',
#    'we gaan sorrowful om geld vragen'],
#   ['you are the black knight', 'jij bent de zwarte ridder'],
#   ['he is sir lancelot', 'hij is sir lancelot'],
#   ['you are the honest knight', 'u bent de eerlijke ridder'],
#   ['you are sir percy', 'u bent sir percy'],
#   ["you are lady guinevere king arthur's lady guinevere",
#    'lady guinevere van koning arthur'],
#   ['you are the kind keeper', 'u bent de aardige bewaarder'],
#   ['we are in a jam', 'we zitten in de nesten'],
#   ['i am sorry to disturb you, citizens',
#    'burgers, het spijt me jullie te storen'],
#   ['we are hungry', 'we hebben trek'],
#   ["i am up at sorrowful's house this afternoon",
#    'ik ben bij sorrowful thuis, deze middag'],
#   ['i am sir lancelot', 'ik ben sir lancelot'],
#   ['you are sir galahad, the greatest one of all',
#    'u bent sir galahead, de beste van allemaal'],
#   ['he is my charger', 'het is mijn strijdros'],
#   ['i am desolate to go', 'ik vind het ook vreselijk'],
#   ['you are a dirty dog', 'u bent een schoft'],
#   ['you are as comical as your charming wife',
#    'u bent net zo geestig als uw vrouw'],
#   ['you are already feeling sleepy', 'u wordt nu al slaperig hoort u mij'],
#   ["she is right just out-smarted you that's all", 'ik liet alle belachelijk'],
#   ['we are going to have to take care of him',
#    'we hebben de zorg voor hem te nemen'],
#   ['he is liable to spoil our plans', 'we konden ergeren de plannen'],
#   ['i am afraid i was talking to the wrong man',
#    'ik vrees dat ik de verkeerde man te hebben het is zo mooi'],
#   ['i am staying right here to guard this money',
#    'ik heb om te blijven kijken naar het geld'],
#   ['i am still guarding this bank, young fellow',
#    'voor dat ik een oogje houden bank, jonge man'],
#   ['he is on 1: 2 favor', 'is de favoriet, een tot twee'],
#   ['i am glad that you are right', 'ik denk dat hij gelijk heeft'],
#   ['i am kind of agreeing at this racket,',
#    'ik ben een beetje groen in deze zaken'],
#   ['we are cleaning up all this after this one anyhow',
#    'en als alles voorbij is ontbonden wij'],
#   ['you are too suspicious', 'je bent veel te achterdochtig'],
#   ['you are a strange sort', 'je bent wel n aparte'],
#   ['you are going it', 'je doet wel duur, zeg'],
#   ['you are clumsy', 'wat ben jij onhandig, zeg'],
#   ['she is the daughter of prince dolgoruki',
#    'zij is de dochter van prins dolgoruki'],
#   ['i am', 'heus'],
#   ['you are a darling', 'je bent een schat'],
#   ['you are germany', 'u bent duitsland'],
#   ['we are ready to carry germany into a new era',
#    'wij zijn klaar om duitsland in het nieuwe tijdperk te loodsen'],
#   ["we are the reich's young manhood",
#    'wij zijn de jonge mannen van het rijk en wij vochten samen bij langemark'],
#   ['you are not dead', 'jullie zijn niet dood'],
#   ['we are dining with mir jutra', 'de koerier wil antwoord'],
#   ['you are to use those to blow your brains out',
#    'schiet uzelf voor het hoofd'],
#   ['she is an angel', 'mary is een engel'],
#   ['we are not meant to know those things', 'dat horen we niet te weten'],
#   ['i am also a doctor, baroness', 'ik ben ook arts'],
#   ['we are friends, you and i', 'we zijn vrienden, jij en ik'],
#   ['i am deeply offended', 'ik ben zeer beledigd'],
#   ['you are deeply offended', 'je bent zeer beledigd'],
#   ['she is having a great career here',
#    'ze heeft een geweldige carrière hier'],
#   ['you are afraid of the police', 'je bent bang voor de politie'],
#   ['i am at your feet', 'ik lig aan je voeten'],
#   ['i am a man of lightning decisions', 'ik neem snel beslissingen'],
#   ['i am happy to hear that you hardly know him',
#    'ik ben blij dat je hem amper kent'],
#   ['he is the greatest tenor since caruso', 'de beste tenor sinds caruso'],
#   ['you are agreed, 1, 000 a night', 'duizend dollar is goed'],
#   ['we are honored by your presence, gentlemen thank you',
#    'uw aanwezigheid is voor ons een grote eer'],
#   ['you are baroni', 'jij bent baroni'],
#   ['i am mad', 'ik ben gek'],
#   ['i am dr vollin', 'ik ben dr vollin'],
#   ['i am not interested in your life story',
#    'ik ben niet geïnteresseerd in uw levensverhaal'],
#   ['you are saying something profound', 'u zegt iets diepgaand'],
#   ['we are bates, sir', 'wij zijn bates, meneer'],
#   ['we are jerry travers', 'wij zijn jerry travers'],
#   ['i am too much protection enough', 'daar ben ik zelf bij'],
#   ['i am no man', 'ik ben geen man'],
#   ['i am beddini', 'ik ben beddini'],
#   ['i am the victim of a designing woman myself',
#    'ik ben zelf het slachtoffer van een mannequin geworden'],
#   ['she is what the french call a passade',
#    'ze is wat de fransen noemen een passade'],
#   ['i am very displeased to meet you really',
#    'ik ben zeer ontstemd dat ik u ontmoet'],
#   ['we are a grand success', 'carisimo, wij zijn een doorslaand succes'],
#   ['we are very proud of our bridal arrangements',
#    'we zijn erg trots op onze bruids-arrangementen'],
#   ['you are in this plot you are cahooting with him',
#    'u zit in deze samenzwering en speelt onder een hoedje met hem'],
#   ['you are the one who married us', 'u bent degene die ons heeft getrouwd'],
#   ['i am dr yogami', 'yogami'],
#   ['i am glad, sir', 'ik ben blij, meneer'],
#   ['he is not in the laboratory', 'hij is niet in t laboratorium'],
#   ['i am delighted to drive a bronson 8',
#    'ik ben verheugd in een bronson 8 te rijden'],
#   ['i am glad to drive a bronson 8', 'ik ben blij in een bronson 8 te rijden'],
#   ['you are talking to your doctor, madame',
#    'u hebt het tegen uw dokter, madame'],
#   ['i am certain of you, madame', 'ik geloof u, madame'],
#   ['i am a bachelor', 'ik ben vrijgezel'],
#   ['she is your wife', 'dat is uw vrouw'],
#   ['she is your wife', 'ze is uw vrouw'],
#   ['she is your wife', 'ze is uw vrouw'],
#   ['she is your wife', 'ze is uw vrouw'],
#   ['i am lucky', 'ik bof maar'],
#   ['we are sailing, we are sailing', 'we varen uit, we varen uit'],
#   ['we are sailing the 28th', 'we varen de 28e uit'],
#   ['we are sailing the 27th', 'we varen de 27e uit'],
#   ['you are sleepy', 'je hebt slaap'],
#   ["i am dracula's daughter", "ik ben dracula's dochter"],
#   ['we are losing all our customers', 'we raken onze klanten kwijt'],
#   ['i am', 'kijk naar mij dat doe ik ook'],
#   ['i am so sorry', 'mijn schuld'],
#   ['he is also the man we are looking for',
#    'en hij is ook de man die we zoeken'],
#   ['he is always troubled when his master is away',
#    'kom eens hier, frisky hij is altijd lastig als de baas er niet is'],
#   ['we are missionaries', 'we zijn missionarissen'],
#   ['i am yours you are mine', 'ik ben van jou, jij bent van mij'],
#   ['we are anxious, but we are not afraid',
#    'we zijn bezorgd, maar we zijn niet bang'],
#   ['you are john cabal', 'u bent john cabal'],
#   ['i am the law here', 'mijn wil is hier wet'],
#   ['you are conscripted', 'uw hulp'],
#   ['i am master here i am the state', 'ik ben hier de baas, ik ben de staat'],
#   ['i am not a stupid woman i am sure', 'daar ga ik van uit'],
#   ['you are not mechanics you are warriors',
#    'jullie zijn geen monteurs, maar soldaten'],
#   ['we are going to put it forward plainly', 'ik ga het de wereld voorleggen'],
#   ['i am a broken man', 'ik ben een gebroken man'],
#   ['i am so interested in all you big athletes',
#    'jullie atleten zijn zo interessant'],
#   ['i am pastor schultz', 'ik ben pastoor schultz'],
#   ['i am trying to be patient, klara', 'ik probeer geduldig te zijn, klara'],
#   ['he is my grandfather', 'hij is mijn grootvader'],
#   ['i am not her child', 'ik ben haar kind niet'],
#   ['i am going to disband mine', 'ik ga het mijne ontbinden'],
#   ['i am going back to sleep', 'ik ga weer slapen'],
#   ['i am from the nearby lamasery', 'ik kom uit het nabije lamaklooster'],
#   ['he is responsible for everything you see here',
#    'hij is verantwoordelijk voor alles wat u ziet'],
#   ["you are still, by the world's standards, a youngish man",
#    'voor n wereldse standaard bent u nog een jeugdige man'],
#   ['he is now your problem', 'hij is nu jouw probleem'],
#   ['i am a citizen and i pay my taxes',
#    'ik ben een burger en betaal belasting'],
#   ["he is different from anyone i've ever known", 'hij is zo anders'],
#   ['you are quite right, my dear', 'daar heeft u gelijk in'],
#   ['we are ready for the ceremony, your majesty', 'het is zover, majesteit'],
#   ['i am', 'lk'],
#   ['you are better now', 'jij bent slimmer nu'],
#   ['you are', 'oja'],
#   ['i am sorry for my mistakes', 'ik heb spijt van mijn fouten'],
#   ['you are my friend', 'u bent mijn vriend'],
#   ['he is notoriously shy, a shrinking violet',
#    'hij is verschrikkelijk verlegen'],
#   ['he is surely a good person', 'walter is ongetwijfeld een uitstekende man'],
#   ['i am referring to wells', 'het gaat om wells w e, i, s'],
#   ['he is really not well', 'het gaat echt niet goed met hem'],
#   ['he is doomed to fail, and deservedly so',
#    'zal dat op een mislukking uitlopen net goed'],
#   ['i am damned to hell', 'ik ben verdoemd'],
#   ['i am the manager', 'ik ben de manager'],
#   ['i am sorry to cause you this inconvenient',
#    'het spijt me van dit ongemak'],
#   ['you are going to pay the bill', 'je gaat de rekening betalen'],
#   ['i am at your mercy', 'ik ben in uw macht'],
#   ["you are mr kirby, aren't you", 'u bent toch mr kirby'],
#   ['you are awful young to be a vice president',
#    'u bent wel jong om vice-president te zijn'],
#   ['you are in time for dinner, yes', 'ja, u bent op tijd voor het eten'],
#   ['she is still staring', 'ze staart me nog aan'],
#   ['you are hereby notified that', 'u wordt hierbij medegedeeld'],
#   ['i am a soldier, sir', 'ik ben een soldaat, meneer'],
#   ['he is not in love with a fish', 'lk bedoelde het niet letterlijk'],
#   ['he is right, ollie she is worthy, all right', 'maar ze heeft al iemand'],
#   ["we are leaving right now aren't we ollie", 'aantreden'],
#   ["i am right you're his only chance",
#    'ik heb gelijk, u bent zijn enige kans'],
#   ['i am mrs wilkes', 'dat ben ik'],
#   ['i am born', 'ik word geboren'],
#   ['i am thinking of you', 'denk s aan mij ik denk ook aan jou'],
#   ['he is taking lower school for preparation',
#    'zoals altijd heeft hij de onderbouw'],
#   ['i am rather hungry', 'ik heb ook best trek'],
#   ['you are right', 'kijk u heeft gelijk'],
#   ['you are so silent', 'wat ben je stil'],
#   ['i am headmaster after all', 'ik ben toch nog directeur geworden'],
#   ['she is pretty', 'jij ze is echt mooi'],
#   ['i am the true king of fools', 'ik ben de ware koning'],
#   ['you are safe here', 'je bent hier veilig'],
#   ['i am what i wish to be', 'ik ben wat ik wenste zijn'],
#   ['you are breaking my wrist', "u breekt m'n pols"],
#   ['you are the servant of god you must help me',
#    'als dienaar van god moet je me helpen'],
#   ['you are my brother', "je bent m'n broer"],
#   ['i am no longer your brother', 'ik ben niet langer je broer meer'],
#   ['she is a witch and must die', 'ze is een heks en moet sterven'],
#   ['i am proud to be the first to sign',
#    'ik ben er trots op dat ik als eerste teken'],
#   ['i am waiting for my brother to speak',
#    "ik wacht op een uitspraak van m'n broer"],
#   ['you are', 'wel, dus'],
#   ['we are happy to take this opportunity', 'dat we u kunnen overhanddoeken'],
#   ["you are miss saunders, aren't you", 'u bent toch miss saunders'],
#   ['i am sick and tired of this contemptible young man',
#    'ik heb genoeg van deze incompetente figuur'],
#   ['he is', 'reken maar'],
#   ["you are running this airline, aren't you", 'jij bent toch de baas hier'],
#   ['we are licked', 'we zijn gezien'],
#   ['i am tired, danny', 'ben ik ook'],
#   ['i am burgomaster of the village', 'ik ben de burgemeester, herr baron'],
#   ['i am glad to see you, benson', 'fijn je te zien, benson'],
#   ['i am inspector krogh of the district police',
#    'inspecteur krogh van de plaatselijke politie'],
#   ['i am glad to see you, inspector', 'blij u te zien, inspecteur'],
#   ['you are poisoned already by your name',
#    'u bent al vergiftigd, door uw naam'],
#   ['i am blacksmith', 'ik ben smid'],
#   ['i am not done, mr president', 'ik ben nog niet klaar, mr president'],
#   ['you are', 'jij bent dat'],
#   ['i am glad for you', 'ik ben blij voor je'],
#   ['he is that', 'hij doet dat'],
#   ['you are', 'echt waar'],
#   ['he is rusted here here', 'hij is behoorlijk geroest'],
#   ['i am oz the great and powerful',
#    'ik ben oz de geweldige en machtige wie zijn jullie'],
#   ['you are', 'u'],
#   ['you are now a member of the legion of courage',
#    'je bent nu lid van het legioen van moed'],
#   ['he is at peace', 'hij rust in vrede'],
#   ['i am heathcliff', 'ik ben heathcliff'],
#   ['i am too stop this thing', 'ik ben wel groot genoeg'],
#   ['i am tired', 'ik ben inderdaad moe'],
#   ['you are tampering with powers reserved to god',
#    'u bemoeit zich met krachten die voorbehouden zijn aan god'],
#   ['i am a biologist', 'ik ben bioloog'],
#   ['he is come right now', 'hij komt er net aan'],
#   ['i am sure you are well-qualified', 'ik weet zeker dat u ook bekwaam bent'],
#   ['i am twice honored', 'ik ben dubbel vereerd'],
#   ['i am not interested in your opinion on cell structure',
#    'ik ben niet geïnteresseerd in uw mening over celstructuur'],
#   ['i am not intimating, dr bulfinch', 'ik geef niets toe, dr bulfinch'],
#   ['you are quick to take credit, dr bulfinch',
#    'u bent wel erg snel met een naamsvermelding, dr bulfinch'],
#   ['we are not departing', 'wij gaan niet weg'],
#   ['he is magnificent', 'hij is geweldig'],
#   ['he is my dog, but who is pedro', 'dat is mijn hond, maar wie is pedro'],
#   ['he is absolutely wrong', 'hij heeft het volstrekt mis'],
#   ['you are most resourceful', 'jullie zijn zeer vindingrijk'],
#   ['you are surprised', 'u bent verbaasd'],
#   ['you are beginning to grow', 'u begint te groeien'],
#   ['i am well aware of that fact', 'daar ben ik me zeer goed van bewust'],
#   ['she is very big', 'hij is inderdaad erg groot'],
#   ['you are here', 'je bent hier binnen'],
#   ['you are growing', 'jullie groeien'],
#   ['he is from now on', 'dat zit hij dus vanaf nu wel'],
#   ['you are moody', 'wat een rare stemming ben je in'],
#   ["i am afraid it's up to you", 'jij moet het maar proberen'],
#   ['i am fisher, mr van meer', 'ik ben fisher, mr van meer'],
#   ['i am your friend', 'ik ben uw vriend'],
#   ['you are in london, mr van meer', 'u bent in londen, mr van meer'],
#   ['i am here merely to talk to you', 'ik ben hier alleen om met u te praten'],
#   ['you are not to take me away', 'ah, u wilt mij hier niet weg halen'],
#   ['i am fond of you, you know', 'ik ben dol op je'],
#   ["you are not talking about the man i'm marrying tomorrow",
#    'niet de man met wie ik morgen trouw'],
#   ['i am sorry, hildy', 'o, sorry'],
#   ['i am sorry', "ja, en hij zet z'n hoed af"],
#   ['i am innocent', 'lk ben onschuldig'],
#   ['i am not wandering all over', 'ik ga niet zoeken'],
#   ['i am looking at you, you murderer', 'ik kijk je aan, moordenaar'],
#   ['you are a stranger in these parts', 'u bent hier vreemd, hé'],
#   ['i am the son of the alcalde', 'ik ben de zoon van de alcalde'],
#   ['he is the son of the alcalde', 'hij is de zoon van de alcalde'],
#   ['i am diego vega, son of his excellency, don alejandro',
#    'ik ben diego vega, zoon van don alejandro'],
#   ['we are collecting taxes from the peons today',
#    'we gaan de belastingen bij de arbeiders ophalen'],
#   ['i am a vega', 'ik ben n vega'],
#   ['i am dazzled', 'ik ben verblind'],
#   ['i am honoured', 'ik ben vereerd'],
#   ['you are zorro', 'je bent zorro'],
#   ['we are not at home', 'we zijn niet thuis'],
#   ['i am honoured', 'ik ben vereerd'],
#   ['you are right, my son', 'je hebt gelijk'],
#   ['she is like the flower', 'ze is net als die bloesem'],
#   ['i am very weary', 'ik ben moe'],
#   ['i am with you', 'ja'],
#   ['you are a mass of intuition', 'je lijkt wel helderziend'],
#   ['i am seth lord', 'ik ben seth lord'],
#   ['you are', 'je bent wakker'],
#   ["you are sensational you mean i'm good", 'je bent een sensatie'],
#   ['you are colossal', 'je bent kolossaal'],
#   ['you are a nervous wreck', 'je bent echt ingestort'],
#   ['you are soaking wet', 'je bent door en doornat'],
#   ['i am mrs de winter now', 'ik ben nu mw de winter'],
#   ['we are going to do nothing', 'wij gaan niks doen'],
#   ['you are too beautiful', 'je bent te mooi'],
#   ['i am going to teach it to him', 'en ik onderwijs het haar'],
#   ['i am near to him', 'ik ben nooit zo dicht geweest bij hun'],
#   ['you are mad, really mad', 'je bent inderdaad gek, volledig gek'],
#   ['i am your slave', 'ik ben uw slaaf'],
#   ['you are indeed silly', 'je bent echt dom'],
#   ['you are my first genius', 'je bent mijn eerste geest'],
#   ['you are not ugly', 'je bent ook niet lelijk'],
#   ['i am in a hurry to see that', 'ik kan niet meer wachten'],
#   ['i am blind', 'ik ben blind'],
#   ['i am this genius', 'ik ben deze geest'],
#   ['i am this physician', 'ik ben deze arts'],
#   ['i am again abu', 'abu'],
#   ['i am a slave', 'jij behoort aan mij'],
#   ['you are an ungrateful', 'je bent nogal ondankbaar'],
#   ['i am not impossible', 'ik ben niet onmogelijk'],
#   ['i am going to return you to the sea', 'ik gooi je terug in zee'],
#   ['i am hungry', 'ik ben hongerig'],
#   ['i am your master, this is not', 'ik ben uw magister, is niet'],
#   ['you are astute, small master, but you are a human',
#    'je bent een snuggere magister, maar je bent zwak en kwetsbaar'],
#   ['i am not your master', 'ik ben uw magister niet meer'],
#   ['i am free', 'ik ben vrij'],
#   ['we are together', 'wij zijn samen'],
#   ['i am not a prince, i am only a thief',
#    'ik ben niet een prins, ik ben slechts een dief'],
#   ['i am by chance there,', 'ik weet niet hoe het komt'],
#   ['i am not right', 'heb ik niet gelijk'],
#   ['you are lucky to be out here', 'u hebt geluk om hier te zijn'],
#   ['you are a smart fellow', 'je bent een slimme kerel'],
#   ['we are in the same boat, huh', 'we zitten in hetzelfde schuitje, hè'],
#   ['we are very proud of you and deeply grateful',
#    'we zijn erg trots op je en diep dankbaar'],
#   ['i am herbert carter, the editor-in-chief',
#    'herbert carter, hoofdredacteur dank u'],
#   ['i am not overdressed', 'ik ben niet te net gekleed'],
#   ['i am interested in our son', 'het gaat me om onze zoon'],
#   ['i am drunk', 'ik ben echt dronken'],
#   ['i am the voice of your subconscious mind',
#    'ik ben de stem van je onderbewustzijn'],
#   ['you are now getting that climax climax',
#    'je gaat nu dat hoogtepunt voor je zien'],
#   ['he is now quite gentle', 'hij is nu heel mak'],
#   ['you are so dominating', 'u bent zo dominant'],
#   ['you are too good for me', 'u bent te goed voor me'],
#   ['i am zolotov', 'ik ben zolotov'],
#   ['we is ruined', 'we zijn geru: ï: neerd'],
#   ['we is ruined', 'ï: neerd'],
#   ['i am not interested in that', 'dat interesseert me niet'],
#   ["i am it's a wonderful hobby", 'het is een geweldige hobby'],
#   ['i am leaving behind me my 50 years of memory',
#    'ik laat 50 jaar achter me'],
#   ['we are not questioning your authority, sir',
#    'we trekken uw autoriteit niet in twijfel'],
#   ['i am beth morgan, as you damn well know',
#    'ik ben beth morgan, zoals jullie weten'],
#   ['he is our guest', 'hij is onze gast'],
#   ['we are a very proud family, mr evans', 'we zijn n heel trots gezin'],
#   ['i am no saint', 'ik ben geen heilige'],
#   ['i am not accustomed to speaking in public',
#    'ik ben niet gewend om in publiek te spreken'],
#   ["i am thinking of the boy's future", "ik denk aan z'n toekomst"],
#   ['i am going down the colliery', 'ik ga de mijn in'],
#   ['she is here without her husband, is it',
#    'ze is hier toch zonder haar man, nietwaar'],
#   ['he is the blood of my heart', 'hij ligt me na aan t hart'],
#   ['you are wonderful', 'u bent geweldig'],
#   ['you are a godsend', 'je bent n geschenk uit de hemel'],
#   ['you are the most insistent person', 'jij geeft ook niet op'],
#   ['you are a liar', 'je bent echt een leugenaar'],
#   ['we are hungry, too', 'wij ook'],
#   ['we are not interested in your expedition anymore',
#    'uw expeditie interesseert ons niet meer'],
#   ['you are a wealthy man, my friend', 'je bent een rijke man'],
#   ['we are surrounded by now', 'we zijn nu omsingeld'],
#   ['we is married already', 'we zijn al getrouwd'],
#   ['i am', 'ik zeg nee'],
#   ['i am so tired what happened, herman', 'had je n klein ongelukje, herman'],
#   ['you are caught in the trap', 'je zit vast in een klem'],
#   ['you are not frightened, are you, sir john',
#    'u bent toch niet bang, sir john'],
#   ['you are lovely, my dear', 'je bent heel mooi'],
#   ['i am holding you too', 'ik arresteer u ook'],
#   ['i am sherazade', 'ik ben sherazade'],
#   ['he is sure to be taken again', 'hij zal zeker opnieuw gepakt worden'],
#   ['you are right, ali', 'je hebt gelijk, ali'],
#   ['we are your friends', 'wij zijn je vrienden'],
#   ['he is really kindhearted', 'hij is echt goedhartig'],
#   ['she is a woman', 'ze is een vrouw'],
#   ['you are sure of that, sherazade', 'ben je daar zeker van, sherazade'],
#   ['you are dreaming', 'je droomt'],
#   ['you are a woman to make men dream',
#    'je bent een vrouw om mannen over te laten dromen'],
#   ['you are not yet on the throne beside him',
#    'je staat nog niet op de troon naast hem'],
#   ['i am going now to find her', 'ik ga nu om haar te vinden'],
#   ['she is sold', 'ze is verkocht'],
#   ['she is sold', 'verkocht'],
#   ['i am bid', 'het bod is'],
#   ['you are safe, sherazade', 'je bent veilig, sherazade'],
#   ['you are the chosen of allah', 'jullie zijn de uitverkorenen van allah'],
#   ['he is here again', 'ze zijn er weer'],
#   ['i am a little more impressed with you', 'je maakt nu meer indruk op me'],
#   ["he is traveling with a lady he'll take one", 'hij reist met een dame'],
#   ['we are very honored tonight, rick', 'we zijn zeer vereerd'],
#   ["you are in rick's", 'de eigenaar van dit café'],
#   ['we are organized underground, like everywhere else',
#    'we zijn georganiseerd'],
#   ['you are in danger you must leave paris', 'je moet weg'],
#   ['we are only interested in two visas', 'we moeten twee visa hebben'],
#   ['you are getting to be your best customer',
#    'u wordt zelf nog uw beste klant'],
#   ['we are concerned about more than casablanca',
#    'het is niet alleen casablanca'],
#   ['we are speaking nothing but english now', 'we spreken alleen engels'],
#   ["he is captain renault's getting broad-minded", 'hoe charmant van renault'],
#   ['you are a man', 'u bent een man'],
#   ['i am also a human being', 'ik ben ook nog mens'],
#   ['you are a sentimentalist', 'blijf daar'],
#   ['i am not an artist', 'ik ben geen kunstenaar'],
#   ['i am so ashamed', 'ik schaam me zo'],
#   ['i am only afraid', 'ik ben alleen maar bang'],
#   ['you are very clever', 'u bent zeer slim'],
#   ['you are that close to real insanity',
#    'u bent zeer dichtbij volledige krankzinnigheid'],
#   ['i am not afraid of you', 'ik ben ook niet bang voor je'],
#   ["you are a fighter, ain't you", 'je bent toch een bokser, he'],
#   ['we are going to find dr frankenstein', 'we gaan dr frankenstein zoeken'],
#   ['he is more dangerous today than he ever was before',
#    'hij is nu gevaarlijker dan ooit'],
#   ['you are going to help him, doctor', 'ga je hem helpen, dokter'],
#   ['you are giving him life', 'je geeft hem leven'],
#   ['he is the first time happy in his life',
#    'hij is voor het eerst in zijn leven gelukkig'],
#   ['you are dr frankenstein', 'u bent dr frankenstein'],
#   ['you are dr kettering', 'jij bent dr kettering'],
#   ['i am not dr kettering', 'ik ben niet dr kettering'],
#   ['i am ygor', 'ik ben ygor'],
#   ['you are the public', 'bent u het publiek'],
#   ['i am old', 'ik ben oud'],
#   ['i am quite willing to overlook the fact',
#    'ik ben best bereid te kijken op het feit'],
#   ['i am one of yourselves', 'ik ben een van u'],
#   ['i am proud of you, ethan', 'ik ben trots op je, ethan'],
#   ['he is a teacher of the jungle law',
#    'hij is de leraar van de junglewetten'],
#   ['he is a wild boy', 'hij is een wilde jongen'],
#   ['he is some poor, lost lad though not my own',
#    'hij is een arm verdwaald kind dat niet van mij is'],
#   ['he is a wolf', 'hij is een wolf'],
#   ['you are like a little panther', 'je lijkt wel een kleine panter'],
#   ['i am a wolf', 'ik ben een wolf'],
#   ['i am with the man-pack now', 'ik hoor nu bij de mannen'],
#   ['i am mowgli of the jungle, back in the night',
#    'ik ben mowgli van de jungle, teruggekomen in de nacht'],
#   ['i am of the jungle', 'ik ben opgegroeid in de jungle'],
#   ["i am the warden of the king's treasure",
#    'ik ben de bewaker van de schat van de koning'],
#   ['i am ashamed', 'ik schaam me'],
#   ['you are standing on my money', 'jij staat op mijn geld'],
#   ['i am beautiful', 'ik ben prachtig'],
#   ['he is mine', 'hij is van mij'],
#   ['he is a witch, i tell you', 'ik zeg je, hij is een heks'],
#   ['you are my friend', 'jij bent mijn vriend'],
#   ['i am of the jungle', 'ik behoor in de jungle'],
#   ["i am quitting, and i'm not drunk, kelly",
#    'ik neem ontslag en ik ben niet dronken, kelly'],
#   ['we are making you a good proposition',
#    'we hebben u een goed voorstel gedaan'],
#   ['she is', 'nog steeds'],
#   ['you are in charleston', 'je bent nu in charleston'],
#   ['she is pretty', 'wat is ze knap'],
#   ['i am a refugee', 'ik ben op de vlucht'],
#   ['i am leaving for the caribbean now', 'ik ga naar het caribisch gebied'],
#   ['he is busy', 'hij is bezig'],
#   ['she is', 'is dat zo'],
#   ['she is', 'is dat zo'],
#   ['she is', 'dat is zo'],
#   ['i am happy', 'dat ben ik ook'],
#   ['i am strictly from corn', 'ik ben'],
#   ["i am so serious it's why i can joke",
#    'ik ben zo serieus, daarom kan ik grappen maken'],
#   ["we are rotting here because there's no fighting",
#    'we kwijnen hier weg, omdat we niet vechten'],
#   ['i am an old man not afraid to fight',
#    'ik ben oud, maar niet bang om te vechten'],
#   ['i am for the bridge', 'ik ben voor de brug'],
#   ['i am for the bridge and against you nothing more',
#    'lk ben voor de brug en tegen jou, dat is alles'],
#   ['i am also for the bridge', 'ik ben ook voor de brug'],
#   ['you are no woman, no fool', 'jij bent geen vrouw, niet gek'],
#   ['you are beautiful', 'jij bent mooi'],
#   ['he is right, fernando', 'hij heeft gelijk, fernando'],
#   ['i am coming', 'ik wil met jullie praten'],
#   ['you are shameless', 'onbeschaamd meisje'],
#   ['you are if you wish', 'als jij dat wilt'],
#   ['he is dangerous only when the moon is full',
#    'hij is gevaarlijk, alleen wanneer de maan vol is'],
#   ['i am what do you beggars want', 'wat willen jullie bedelaars'],
#   ['you are jealous', 'je bent echt jaloers'],
#   ['i am not a frightened girl', 'ik ben geen bang meisje'],
#   ["i am afraid it's not very frightening",
#    'ik ben bang dat het niet erg beangstigend is'],
#   ['she is dead living and dead', 'ze is dood levend en dood mrs'],
#   ['she is charming and clever, miss emily',
#    'ze is charmant en slim, miss emily'],
#   ['we are her owners', 'wij zijn nu de eigenaars'],
#   ['he is a good lad', 'dat is ie zeker'],
#   ['you are late, monsieur claudio', 'u bent laat'],
#   ['he is too busy today', 'hij heeft vandaag geen tijd'],
#   ['i am a police officer, not a psychic', 'ik ben geen helderziende'],
#   ['i am you heard, monsieur garron', 'hoort u dat, monsieur garron'],
#   ['i am not a theorist', 'ik theoretiseer niet'],
#   ['you are wrong, monsieur', 'u vergist zich'],
#   ['i am but a mechanic', 'ik ben maar monteur'],
#   ['you are very generous', 'u bent gul'],
#   ['we are merely sharing our good fortune with you',
#    'we hebben nog veel meer'],
#   ["you are also the girl's father", 'je bent toch ook haar vader'],
#   ['i am a doctor', 'ik ben arts'],
#   ['i am his superior officer', 'ik ben zijn superieur'],
#   ['he is cruel and mean', 'hij is wreed en gemeen'],
#   ['you are playing with fire, bernadette', 'je speelt met vuur, bernadette'],
#   ['i am vital dutour, the imperial prosecutor',
#    'ik ben victor dutour, de procureur'],
#   ['you are the bearer of a great name', 'u draagt n belangrijke naam'],
#   ['you are the postulant from lourdes', 'ben jij de postulant uit lourdes'],
#   ['you are a hundred times more worthy', 'u bent honderd keer meer waard'],
#   ['i am a stranger here', 'ik ben een vreemde hier'],
#   ['you are now in heaven and on earth', 'je bent nu in de hemel en op aarde'],
#   ['you are a lady, therefore you must go first',
#    'jij bent een dame, dus jij moet eerst gaan'],
#   ['you are english', 'u, u bent engels'],
#   ['we are happy to see you, my friend',
#    'we zijn blij je te zien, mijn vriend'],
#   ['i am indeed enchanted', 'ik ben onder de indruk'],
#   ['you are very fascinating, my dear', 'u bent heel fascinerend, mijn lieve'],
#   ['you are far too beautiful to act like a child',
#    'u bent veel te mooi om u als een kind te gedragen'],
#   ['you are my little friend', 'je bent mijn kleine vriend'],
#   ['i am sure he fell here', 'ik weet zeker, dat hij hier viel'],
#   ['we are pledged now, amara', 'we zijn nu aan elkaar verbonden, amara'],
#   ['you are the cleverest thief among us',
#    'jij bent de beste dief van ons allen'],
#   ['i am no thief', 'ik ben geen dief'],
#   ['you are welcome, ali baba', 'welkom, ali baba'],
#   ['he is magnificent, my lady', 'hij is geweldig, milady'],
#   ['he is the greatest warrior in all the land',
#    'hij is de grootste strijder in het hele land'],
#   ['we are camped beside the pool of midnight, my lady',
#    'we staan hier naast het meer van middernacht, milady'],
#   ['you are not harmed', 'u bent niet gewond'],
#   ['you are ali', 'jij bent ali'],
#   ['i am no spy', 'ik ben geen spion'],
#   ['he is no fool, he will watch for every trick',
#    'hij zal iedere val van ons herkennen'],
#   ['she is your daughter', 'het is jouw dochter'],
#   ['you are a breed apart', 'jullie zijn een apart soort'],
#   ['you are a master of trickery, prince cassim',
#    'u bent een meester in bedrog, prins cassim'],
#   ['you are a stranger among us', 'u bent een vreemdeling onder ons'],
#   ['i am abu radi, merchant of basra', 'ik ben abu radi, koopman uit basra'],
#   ['you are my honored guest', 'je bent mijn geëerde gast'],
#   ['i am jonathan bewste', 'ik ben jonathan brewster'],
#   ['i am happy too, and tired', 'ik ben ook gelukkig, en moe'],
#   ['i am buffalo bill cody', 'ik ben buffalo bill cody'],
#   ["we are definitely in the man's way here let's find", 'we staan in de weg'],
#   ['i am preparing a more detailed report for your consideration',
#    'een gedetailleerder verslag volgt'],
#   ['we are', 'oh ja'],
#   ['i am going to this reception, gregory',
#    'ik ga naar die receptie, gregory'],
#   ['he is not listening', 'hij luistert niet'],
#   ['you are dopey', 'je bent dom'],
#   ['you are a bass singer', 'je bent wel een bas'],
#   ['i am not going to reigelberg', 'ik ga niet naar reigelberg'],
#   ['we are here on our honeymoon', 'we zijn hier op huwelijksreis'],
#   ['i am baron latos from transylvania',
#    'ik ben baron latos uit transsylvanië'],
#   ['i am the most widely misquoted man in america',
#    'niemand wordt zo vaak fout geciteerd als ik'],
#   ["you are laura hunt, aren't you", 'jij bent laura hunt, toch'],
#   ['you are head of the commissary yes, sir', 'jij beheert onze voorraad'],
#   ['i am very easy to convince', 'ik ben erg makkelijk te overtuigen'],
#   ['she is too fair to look upon', 'ze is te eerlijk om naar te kijken'],
#   ['you are my master', 'je bent mijn meester'],
#   ['i am out', 'ik ben eruit'],
#   ['i am in a very sensitive profession', 'ik heb een zeer gevoelig beroep'],
#   ['i am a quack', 'ik ben een kwakzalver'],
#   ['i am slightly disgusted and very disappointed',
#    'ik vind het een beetje stuitend en zeer teleurstellend'],
#   ['i am very disappointed in you', 'u stelt me erg teleur'],
#   ['i am frightened', 'ik ben bang'],
#   ["she is beautiful, isn't she and desirable",
#    'ze is mooi, niet dan, en begeerlijk'],
#   ['you are kind, uncle saul', 'je bent goedaardig, oom saul'],
#   ['we are honored at your presence', 'we zijn vereerd op uw aanwezigheid'],
#   ['i am francisco de los santos, el mundo, buenos aires',
#    'ik ben francisco de los santos van el mundo, buenos aires'],
#   ['i am still in excellent health', 'ik ben nog kerngezond'],
#   ['he is a liar', 'hij liegt'],
#   ["i am grateful for your excellency's assistance",
#    'ik dank uwe excellentie voor uw hulp'],
#   ['you are convinced that the planes came from a carrier',
#    'weet u zeker dat ze van een vliegdekschip kwamen'],
#   ['you are a sailor in the japanese navy yes',
#    'je bent matroos in de japanse marine'],
#   ['you are excused, gentlemen', 'u kunt gaan, heren'],
#   ['i am at your service, general', 'zeker, generaal'],
#   ['i am thoroughly ashamed', 'ik schaam me diep'],
#   ['i am not qualified to vote', 'ik stem niet'],
#   ['he is trampling out the vintage', 'hoe hij mensen allen leert'],
#   ['you are crying, arlita', 'je huilt arlita'],
#   ['i am dr chung', 'ik ben dokter chung'],
#   ['i am for france', 'bij frankrijk'],
#   ["you are sore, aren't you", 'je bent echt kwaad, hè'],
#   ['we are in baía', 'we zijn in bahia'],
#   ['you are very funny fellow', 'wat ben jij n grapjas'],
#   ['you are off the beat', 'jullie dansen uit de maat'],
#   ['you are too proud', 'je bent te trots'],
#   ['i am as i am', 'ik ben zoals ik ben'],
#   ['i am found out', 'marie de verdrietige marie'],
#   ['i am well informed', 'o ja, pierre-françois'],
#   ['i am baron latos', 'wie bent u ik ben baron latos'],
#   ['i am baron latos', 'ik ben baron latos'],
#   ['he is authorized to contact all agents known to you',
#    'hij mag contact hebben met alle agenten die u kent'],
#   ['we are doing our most important work right now',
#    'we zijn bezig met zeer belangrijk werk'],
#   ['he is forbidden to contact any agents known to you',
#    'hij mag geen contact hebben met agenten die je kent'],
#   ['you are to send it immediately this is important',
#    'je moet het meteen versturen, het is belangrijk'],
#   ['you are still not strong', 'je bent nog niet aangesterkt'],
#   ['we are fishermen you saw our permits', 'maar we wilden net uitvaren'],
#   ['i am in command here', 'ik voer t bevel'],
#   ['i am dr graff', 'ik ben dr graff'],
#   ['he is not in his room', 'is hij niet in zijn kamer'],
#   ['you are telling the truth', 'je zegt de waarheid'],
#   ['i am', 'nee, ik'],
# ...
#   ['i am like you, a priest, but a jesuit oh',
#    'ik ben zoals jij, een priester, maar een jezuïet'],
#   ["we are both fine, ma'am", 'het gaat prima met ons, mevrouw'],
#   ['he is the natural successor', 'hij is de eigenlijke opvolger'],
#   ['you are in the right, they in the wrong',
#    'u hebt het bij het rechte eind'],
#   ['i am right sometimes, you know', 'ik heb weleens gelijk, hoor'],
#   ['i am deeply honored to be here today',
#    'het is een grote eer om hier vandaag te zijn'],
#   ['i am that man in the painting', 'ik ben die man van dat schilderij'],
#   ['you are one of the five', 'je bent één van de vijf'],
#   ['i am not gonna let anything happen to you',
#    'ik ben niet gonna laat iets gebeuren met je'],
#   ['you are', 'je bent'],
#   ['i am proud of each and every one of you',
#    'wat er vandaag ook gebeurt, ik ben trots op jullie allemaal'],
#   ['i am seeing someone', 'ik heb iemand'],
#   ['you are formidable', 'je bent geweldig'],
#   ['i am so sorry, can we reschedule', 'sorry, een ander keertje'],
#   ['you are a very brave girl', 'jij bent een heel moedig meisje'],
#   ['we are from the department of child and family services',
#    'wij zijn van jeugdzorg'],
#   ['i am out of ideas', 'ik zou het echt niet meer weten'],
#   ['i am and i intend to prove that to you',
#    'en ik ben van plan om dat te bewijzen'],
#   ['we are cooking with c-h-4 ohh', 'we koken met ch4'],
#   ['i am not gonna', 'ik ga niet'],
#   ['i am a democrat', 'dat ben ik wel'],
#   ['he is the leader of your party, susan', 'hij is de leider van je partij'],
#   ['i am well', 'het gaat ook goed fijn'],
#   ['i am going to earn that from you', 'dat recht ga ik verdienen'],
#   ['we are officers of the law', 'we zijn agenten'],
#   ['you are there for her, she is there for you',
#    'jij bent er voor haar, zij is er voor jou'],
#   ['he is', 'dat gaat hij doen'],
#   ['we are now in the year 4032', 'we zijn nu in het jaar 4032'],
#   ['you are gonna save a lot of folks, doc',
#    'jij gaat een hoop mensen redden, dok'],
#   ['i am sincerely trying to-to', 'ik probeer oprecht om om'],
#   ['i am not threatened by it', 'ik word er niet door bedreigd'],
#   ['i am doing what pilcher would have done',
#    'ik doe wat pilcher gedaan zou hebben'],
#   ['she is still bleeding pretty bad', 'ze heeft een fikse bloeding'],
#   ['you are going to ortho to get that checked out',
#    'je laat orthopedie er even naar kijken'],
#   ['we are not losing this guy', 'we gaan deze man niet verliezen'],
#   ['we are running a few tests right now', 'we zijn bezig hem te onderzoeken'],
#   ['he is such a good nurser', 'wat een goede drinker'],
#   ['you are such a macho cliché', 'wat ben jij een machocliché zeg'],
#   ['we are definitely on the radar', 'we zitten absoluut in hun vizier'],
#   ['i am not a violent person', 'ik ben geen gewelddadig persoon'],
#   ['she is the lord and master', 'zij is heer en meester'],
#   ['we are gonna be fine, leonard', 'het komt in orde, leonard'],
#   ['he is obsessing over billy mcbride',
#    'hij is geobsedeerd door billy mcbride'],
#   ['i am calling in regards to your little sister, frannie',
#    'ik bel met betrekking tot je zus, frannie'],
#   ['we are not the only ones with a problem',
#    'wij zijn niet de enigen met problemen'],
#   ['you are the one who makes all the noise', 'jij maakt alle herrie'],
#   ['you are welcome, sir', 'graag gedaan, meneer'],
#   ['he is not like his father', 'hij is niet zoals zijn vader'],
#   ['he is charged with disorderly conduct',
#    'de aanklacht is wanordelijk gedrag'],
#   ['i am working for you', 'ik werk al voor je'],
#   ['we are so far away from everything', 'we zitten overal ver vandaan'],
#   ['he is hell-bent on pressing charges',
#    'hij wil haar met alle geweld aanklagen'],
#   ['you are super-smart', 'je bént superslim'],
#   ['i am great', 'prima'],
#   ['i am a florrick fanatic', 'ik ben florrick fan'],
#   ['i am an honest-to-god, number one florrick fanatic',
#    'ik ben een hele echte fan van florrick'],
#   ['i am ripped', 'ik ben opgelicht'],
#   ['she is responsible for that', 'zij is daar verantwoordelijk voor'],
#   ['you are such a robust personality,',
#    "je bent zo'n sterke persoonlijkheid,"],
#   ['he is the most private person that i know',
#    'hij is erg op zijn privacy gesteld'],
#   ['you are doing fantastic', 'jij doet het fantastisch'],
#   ["i am now, i haven't made up my mind yet", 'ik heb nog niks beslist'],
#   ['you are the first to know', 'u bent de eerste die het weet'],
#   ["you are steward of the queen's household now",
#    'u bent nu hofmeester in de hofhouding van de koningin'],
#   ['you are not needing a governess now',
#    'u hebt niet langer een gouvernante nodig'],
#   ['you are going to kensington palace', 'ga je naar het kensington palace'],
#   ['she is very young and rather delicate',
#    'ze is nog erg jong en zeer broos'],
#   ['i am in no hurry', 'ik heb geen haast'],
#   ['i am very good at mending, mrs jenkins',
#    'ik ben goed in herstelwerk, ms jenkins'],
#   ["she is so young, ma'am", "ze is nog zo jong, ma'am"],
#   ["she is small but she ain't no midget no",
#    'ze is wel klein maar beslist geen dwerg'],
#   ['i am not familiar with that style', 'ik ben niet bekend met die stijl'],
#   ['he is someone who is clever at stealing hearts',
#    'hij is heel goed in het stelen van iemands hart'],
#   ["we are so often in each other's company",
#    'we zijn zo vaak in elkaars gezelschap'],
#   ["i am sure he'll be here soon, ma'am", "hij zal zo wel komen, ma'am"],
#   ['you are very young', 'u bent erg jong'],
#   ['i am 18', 'ik ben 18'],
#   ['you are not old, lord m', 'u bent niet oud, lord m'],
#   ["i am no longer surprised by the queen's behaviour",
#    'ik ben niet langer meer verrast door het gedrag van de koningin'],
#   ["i am beyond peaches, ma'am",
#    "ik ben voorbij het stadium van perziken, ma'am"],
#   ['i am sorry, mama', 'het spijt me, mama'],
#   ['you are a strange one, miss skerrett',
#    'je bent een vreemd meisje, ms skerrett'],
#   ['you are a despicable human being', 'jij bent een verachtelijke mens'],
#   ["you are what's wrong with the world",
#    'jij bent wat er verkeerd loopt in deze wereld'],
#   ['i am offering both sides the opportunity to blink',
#    'ik laat de partijen elkaar in de ogen kijken'],
#   ['i am not a crazy person', 'ik ben niet gek'],
#   ['i am hades', 'ik ben hades echt'],
#   ['i am so right', 'ik heb zo gelijk'],
#   ['i are you sure about this', 'ben je daar zeker van'],
#   ['i am here for you 24 hours a day', 'ik ben hier 24 7'],
#   ['i am very nice to you', 'ik ben heel lekker voor jou'],
#   ['i am a prisoner of war', 'ik ben een krijgsgevangene'],
#   ['you are a funny boy', 'je bent een grapjas, hè'],
#   ['i am beginning to understand the roots of your success',
#    'ik begin de basis van je succes te begrijpen'],
#   ['you are too noble', 'daar ben je te nobel voor'],
#   ['you are not under arrest at this point',
#    'jullie zijn nu nog niet gearresteerd'],
#   ['i am simply a man', 'ik ben gewoon een man'],
#   ['we are pursuing other leads', 'we volgen andere sporen'],
#   ['we are brother and sister', 'we zijn broer en zus'],
#   ['we are not going away, sir', 'we gaan niet weg, meneer'],
#   ['i am dead', 'ik kan sterven'],
#   ['you are an amazing person', 'je bent een geweldig mens'],
#   ['he is a true artist', 'hij is een echte artiest'],
#   ['you are not just a work of art, callie',
#    'je bent niet alleen een kunstwerk, callie'],
#   ['we are not in love', 'we zijn niet verliefd'],
#   ['you are not going out dressed like that', 'je gaat zo niet naar buiten'],
#   ['he is the son of angus mcdonough', 'hij is de zoon van angus mcdonough'],
#   ['you are now officially the owner of positivity',
#    'je bent nu officieel de eigenaar van positivity'],
#   ['i am hungry like the wolf', 'ik ben hungry like the wolf'],
#   ['we are an energy drink company', 'we zijn een energiedrankbedrijf'],
#   ['i am gonna need something to trigger the vision',
#    'ik heb iets nodig om de visioen te triggeren'],
#   ['he is the chaos killer, liv', 'hij is de chaos killer, liv'],
#   ['you are his only alibi', 'jij bent zijn enige alibi'],
#   ['she is so pissed off', 'zij is zo kwaad'],
#   ['we are going to silicon beach', 'wij gaan naar silicon beach'],
#   ["you are monty's butler oh, yeah", "jij bent monty's butler"],
#   ["i am i'm out of my depth uh", 'dit is niet mijn vakgebied'],
#   ['i am no longer connected to any ncis servers',
#    'ik heb geen verbinding met ncis servers meer'],
#   ['you are not a venture capital investor',
#    'je bent geen durfkapitaal investeerder'],
#   ['he is serving his time', 'hij moet zijn tijd dienen'],
#   ['we are chasing a killer, here', 'we jagen op een moordenaar'],
#   ['i am not gonna let her do it to mine', 'dat sta ik niet toe'],
#   ["i am happy to report i'm feeling much better",
#    'ik ben blij te kunnen melden dat ik mij veel beter voel'],
#   ['we are as strong as they are hell, stronger',
#    'we zijn zo sterk als zij zijn hel, sterker'],
#   ['i am his wife and the mother of his children',
#    'ik ben zijn vrouw en de moeder van zijn kinderen'],
#   ['you are not simple but you are disobedient',
#    'jij bent niet simpel maar je bent ongehoorzaam'],
#   ['you are just all all all sunshine',
#    'jullie zijn gewoon allemaal zonnetjes'],
#   ['i am honored you could join me', 'een eer dat u me komt vervoegen'],
#   ['we are going after whoever murdered these people',
#    'we gaan achter gelijk wie aan die deze mensen vermoordde'],
#   ['i am a complete physical coward', 'ik ben een volledig fysieke lafaard'],
#   ['i am in new orleans for rest and relaxation',
#    'ik ben in new orleans voor de rust en de ontspanning'],
#   ['she is coming with me', 'zij gaat met mij mee'],
#   ['you are an amateur, cillian', 'jij bent een amateur, cillian'],
#   ['i am never swimming there again', 'ik ga daar nooit meer zwemmen'],
#   ['we are united', 'wij zijn verenigd'],
#   ['i am', 'het spijt me'],
#   ['you are strong enough', 'jij bent sterk genoeg'],
#   ['i am good', 'ik probeer het'],
#   ['we are suing your client',
#    'we klagen uw cliënt aan waarvoor contractbreuk'],
#   ['i am not offering you a job', 'er is geen baan'],
#   ['we are pushing the boundaries of what is magically possible',
#    'we zoeken de grenzen op van wat er magisch mogelijk is'],
#   ['you are margo', 'jij bent margo'],
#   ['you are under the influence of a probability spell',
#    'je bent onder de invloed van een waarschijnlijkheidsspreuk'],
#   ["i am fabulous, aren't i", 'ik ben geweldig, ben ik niet ja'],
#   ['we are going to fillory to save everything',
#    'we gaan naar fillory om alles te redden'],
#   ['i am trying as hard as i can', 'ik probeer zo goed mogelijk als ik kan'],
#   ['we are going to fillory', 'we gaan naar fillory'],
#   ["i am he's right", 'hij heeft gelijk'],
#   ['you are 100 to blame', 'voor 100'],
#   ['i am extremely sorry about that no', 'ja, ik vind dat erg vervelend'],
#   ['you are a genius, mrs mccarthy', 'u bent een genie, mrs mccarthy'],
#   ['you are not to blame', 'u treft geen schuld'],
#   ['i am not going anywhere until i', 'ik ga nergens heen totdat ik'],
#   ['he is not on the guest list', 'hij is niet op de gastenlijst'],
#   ['i am not leader of ghost mountain',
#    'ik ben niet de leider van ghost mountain'],
#   ['i am to blame for what happened to her',
#    'het is mijn schuld wat er met haar gebeurd is'],
#   ['you are the boss, right', 'u bent de baas, toch'],
#   ["i am my mother's son", 'ik ben een zoon van mijn moeder'],
#   ['we are disregarded because, unless we make them money,',
#    'wij worden genegeerd tenzij we geld opbrengen'],
#   ['you are part of the defense team', 'jij bent bij de verdediging'],
#   ['you are my people', 'jullie zijn mijn mensen'],
#   ['we are winning', 'wij winnen'],
#   ['he is a con man', 'hij is een oplichter'],
#   ['you are a terrible friend', 'je bent een verschrikkelijke vriendin'],
#   ['i am absolutely certain of it', 'ik ben er absoluut zeker van'],
#   ['i am not okay with this', 'ik voel me hier niet goed bij'],
#   ['i am sir gaston', 'ik ben heer gaston'],
#   ['i am not stalling', 'ik rek geen tijd'],
#   ['she is a peach', 'ze is een schat'],
#   ['you are a world-class engineer', 'je bent een ingenieur van wereldklasse'],
#   ['you are aware, i never went to georgetown',
#    'je weet toch dat ik niet op georgetown zat'],
#   ['you are a joyless fun-sucker', 'je bent een vreugdeloze plezierbederver'],
#   ['we are all very concerned', 'we zijn allemaal erg bezorgd'],
#   ['we are not fighting', 'we maken geen ruzie'],
#   ['i am not an invalid', 'ik ben geen invalide'],
#   ['he is wearing', 'deze bejaarde man wordt vermist'],
#   ['i am single, for now', 'ik ben momenteel vrijgezel'],
#   ['i am not in a rush', 'ik heb geen haast'],
#   ["she is the kindest, sweetest woman you'll ever meet",
#    'ze is de aardigste, liefste vrouw die je ooit hebt ontmoet'],
#   ['i am starving', 'ik heb honger'],
#   ['i am a selfish dancer', 'ik ben een egoïstische danser'],
#   ['i am in your home with your family', 'ik ben in jouw huis met jouw gezin'],
#   ['i am not dangerous to your friends',
#    'ik ben niet gevaarlijk voor je vriendin'],
#   ['i am free', 'ik ben vrij'],
#   ['we are not lovers', 'wie zijn geen liefdespaar'],
#   ['i am a lawyer, greg', 'ik ben een advocaat, greg'],
#   ['you are one smart son of a bitch', 'jij bent een slimme klootzak'],
#   ['i am protecting you', 'ik bescherm jou'],
#   ['he is safe, and he is cared for', 'hij is veilig, hij wordt verzorgd'],
#   ["he is my guest i don't want him near connor",
#    'met mijn goedkeuring, drummond'],
#   ['you are my girl who must leave me', 'maar dit biedt me een uitweg'],
#   ['he is wrong, edmund, and you know it',
#    'ik wil de waarheid horen die ken ik niet'],
#   ['i am not that', 'welnee'],
#   ['you are sleepless', 'ga zitten'],
#   ['she is jewish raised as an english woman',
#    'ze denkt dat de politie de mensen van haar geloof niet beschermt'],
#   ['i am', 'het is miss susan'],
#   ['you are all together too tough-minded for such suspicions',
#    'zo lichtgevoelig ben je niet'],
#   ['you are not their killer', 'dat dit niet mijn schuld is'],
#   ['she is almost a celebrity in these parts', 'dat doe ik ook'],
#   ['we are many we are everywhere', 'we zijn met velen, we zijn overal'],
#   ['you are one hot-headed police officer',
#    'jij bent een driftige politieagent'],
#   ['we are kill', 'dus moorden we'],
#   ['you are so weird', 'jij bent echt raar'],
#   ['i am your brother you belong to me', 'ik ben je broer, je hoort bij mij'],
#   ['i am calling for you', 'hunters s01e07 kissing the machine vertaling:'],
#   ['you are why', 'milo'],
#   ['she is not a creature', 'zij is geen schepsel'],
#   ['i am your brother', 'ik ben je broer'],
#   ['you are', 'o, maar dat ben je wel'],
#   ['i am your prisoner', 'ik ben je gevangene'],
#   ['we are all part of one another', 'we zijn allemaal een deel van de ander'],
#   ['i am often with woman', 'ik ben vaak bij vrouwen'],
#   ['you are privy to information that is beyond classified',
#    'jij hebt toegang tot informatie die meer als geclassificeerd is'],
#   ['you are a part of me', 'jij bent een deel van mij'],
#   ['you are all good', 'je bent helemaal in orde'],
#   ['you are no longer in command here', 'jij hebt hier niet meer de leiding'],
#   ['we are we with support', 'hebben we ondersteuning'],
#   ['you are our brother', 'jij bent onze broeder'],
#   ['you are no longer in command here',
#    'jij hebt hier niet langer de leiding'],
#   ['he is no danger', 'hij is geen gevaar'],
#   ['she is exalted', 'ze is een exalted'],
#   ['you are not like the other humans',
#    'jij bent niet zoals de andere mensen'],
#   ['you are the one who can stop my enemies',
#    'jij bent degene die mijn vijanden kan stoppen'],
#   ['we are going home', 'wij gaan naar huis'],
#   ['you are no longer part of this family',
#    'jij bent niet langer een deel van deze familie'],
#   ['you are drug dealers, murderers, and terrorists',
#    'het zijn drugsdealers, moordenaars en terroristen'],
#   ['we are detaining them', 'we houden ze vast'],
#   ['you are no longer in command here',
#    'jij hebt niet langer hier de leiding'],
#   ['you are a true patriot', 'je bent een echte patriot'],
#   ...]]
