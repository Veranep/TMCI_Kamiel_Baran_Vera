# %% [markdown]
# # Preprocess Notebook
#
# This notebook is dedicated to the preprocessing of the data. The input file is in the format of an .tmx file. The steps that are currently being done are:
# 1. Extract lines
# 2. Store surplus
# 3. Pair lines
# 4. Clear punctuation
# 5. Sample the dataset
#
# ## Imports
# Below are all the libraries used for this notebook

# %%
import unicodedata
import re
import pickle
import copy

import nltk

# %% [markdown]
# ## Cleaning the data
# This function includes all cleaning steps of the data. It reads the tmx file, takes out the lines that interest the model, removes unnecessary tags, and pairs the lines as englist-dutch respective order. Afterwards, it writes the data in a pickle for further usage. A pickle reading function with an optional limiter has also been included.

# %%
def clean(input_location: str, output_location: str, chunk_size = 1048576):
    """ This function takes a file, reads it, separates it, and saves it
    to a document via pickling it. Chunk size means the number of characters
    which roughly converts to the amount of bytes. Default setting is equal to a
    Megabyte. """
    
    # Opening the filestreams
    input_file = open(input_location, "r")
    output_file = open(f"data/{output_location}", "wb")
    
    # Reading the first chunk
    chunk = input_file.read(chunk_size)
    
    waiting_single = [[], []]              # Variable to hold the line pairs
    extra = " "                            # Variable to hold extra strings
    
    while chunk:
        #print(chunk+extra+"\n\n")
        lines, extra = getLines(extra + chunk)
        #print(f"{lines}\n{extra}")
        if not lines:
            chunk = input_file.read(chunk_size)
            continue
        waiting_single, pairs = pair(waiting_single, lines)
        pickle.dump(pairs, output_file)
        chunk = input_file.read(chunk_size)
    input_file.close()
    output_file.close()

# %%
def pair(temp: list, lines: list) -> list:
    """ Takes two list, one with all the unpaired lines, and a list with possibly an
    unpaired single and a tag. """
    
    results = list()
    for tag, line in lines:
        if len(temp[0]) == 2 and f"{temp[1][0]}{temp[1][1]}" != "ennl":
            # If the pair is wrongly ordered
            print(temp)
            print(results)
            raise Exception("Line mismatch occured")
        elif len(temp[0]) == 2:
            # If the pair is correct
            results.append(copy.copy(temp[0]))
            temp = [[],[]]
        # The part which adds a line to be paired
        temp[0].append(line)
        temp[1].append(tag)
    return (temp, results)

# %%
def getLines(temp_str: str) -> (list, str):
    """ Takes a string, extracts the lines with actual quotes.
    Returns the lines and the string left after the last line. """
    
    lines = re.findall(r"<tuv.+?(?=</seg>)</seg>", temp_str)
    # If there is no lines to find, pass the string as a whole
    if not lines:
        return [[], temp_str]
    # If there is a line, this part extracts the text after
    # the last scanned line
    if lines[-1] != temp_str[-len(lines[-1]):]:
        remnants = ""
        for i in range(1, len(temp_str)-len(lines[-1])):
            if lines[-1] == temp_str[-(len(lines[-1])+i):-i]:
                break
            else:
                remnants += temp_str[-i]
    # Erases the parts we are not interested in
    lines = [(line[15:17], line[24:-6]) for line in lines]
    return (lines, remnants[::-1])

# %% [markdown]
# ## Pickle Functions:

# %%
def readPickle(pickle_off: str, limiter = -1):
    """ Read the pickle either in a limited amount of chunks or all
    of them at once. """
    objects = []
    file_stream = open(pickle_off, "rb")
    while limiter != 0:
        try:
            objects.append(pickle.load(file_stream))
            limiter -= 1
        except EOFError:
            break
    file_stream.close()
    return objects

# %%
def processPickle(pickle_off: str, process=lambda x:x, limiter = -1, store=False):
    """ Takes in a pickle, reads it in chunks and applies the process function to it in each chunk.
    Depending on the store value, it either stores the results in a list and returns it or returns nothing.
    The process function can only have one input which is the read object from the pickle. """
    
    objects = []
    file_stream = open(pickle_off, "rb")
    
    while limiter != 0:
        try:
            if store:objects.append(process(pickle.load(file_stream)))
            else:process(pickle.load(file_stream))
            print("Chunk processed.")
            limiter -= 1
        except EOFError: # When there is nothing else to read
            break
    file_stream.close()
    if store: return objects

# %%
def getLen(lines: list)->int:
    """ Takes a list of lines, prints and returns the length. """
    l = len(lines)
    print(f"The length of this chunk is {l} lines")
    return l

# %%
# In order to get the full length of a pickle, we do
full_l = sum(processPickle("data/sample1.pkl",process = getLen, store = True))
print(f"The total length of pickle is {full_l} lines")
# Out:
# The length of this chunk is 14635 lines
# Chunk processed.
# The length of this chunk is 14605 lines
# Chunk processed.
# The length of this chunk is 13056 lines
# Chunk processed.
# The length of this chunk is 13187 lines
# Chunk processed.
# The length of this chunk is 13669 lines
# Chunk processed.
# The length of this chunk is 14008 lines
# Chunk processed.
# The length of this chunk is 13855 lines
# Chunk processed.
# The length of this chunk is 13441 lines
# Chunk processed.
# The length of this chunk is 13209 lines
# Chunk processed.
# The length of this chunk is 13928 lines
# Chunk processed.
# The length of this chunk is 8941 lines
# Chunk processed.
# The total length of pickle is 146534 lines

# %% [markdown]
# ## Sampling

# %%
# The pattern to tokenize each sentence
pattern = r'''(?x)           # set flag to allow verbose regexps
     (?:[a-z]\.)+            # abbreviations, e.g. U.S.A.
   | [a-z0-9]+(?:[-'][a-z0-9]+)*[,:;']?  # words with optional internal hyphens
'''

def cleanPunc(line: str) -> list:
    """ Takes a string, makes all of them lowercase and tokenizes it, getting rid of unwanted characters. """
    return nltk.regexp_tokenize(unicodeToAscii(line.lower()), pattern)

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def samplingDataset(line_pairs: list, sampleCheck) -> list:
    """ Takes a list of tokenized pairs, and a function to check one of the tokenized lists.
    Extracts the ones that return true for the check. """
    sample = list()
    for en, nl in line_pairs:
        temp_en = cleanPunc(en)
        temp_nl = cleanPunc(nl)
        if sampleCheck(temp_en, temp_nl):
            sample.append([" ".join(temp_en), " ".join(temp_nl)])
    return sample

def samplingMethod1(line: list) -> bool:
    """ Takes in a list of strings. Checks if it has the given words in given indexes depending on
    the list. """
    
    # This list is formed of lists of an index and the possible words that are supposed to be
    # in that index
    check_list = [[0, ["he", "she", "it"]], [1, ["is"]]]
    
    for index, words in check_list:
        if len(line) <= check_list[-1][0] or not line[index] in words:
            return False
    return True

def samplingMethod2(line: list) -> bool:
    """ Takes in a list of strings. Checks if it has the given words in given indexes depending on
    the list and is in the right size. """
    
    # This list is formed of lists of an index and the possible words that are supposed to be
    # in that index
    check_list = [[0, ["he", "she", "we", "i", "you"]], [1, ["is", "are", "am"]]]
    
    for index, words in check_list:
        length = len(line)
        if length > 10 or length <= check_list[-1][0] or not line[index] in words:
            return False
    return True

def samplingMethod3(line1: list, line2: list) -> bool:
    """ Takes in two lists, checks their length. """
    
    if len(line1) > 20 or len(line2) > 20:
        return False
    return True
    

def pickleSample(output_location: str, sampleCheck=lambda x:True):
    """ Takes in an output location, and a function to apply sampling with. Uses the process pickle
    function to chunk the pickle and apply the sampling in each chunk. Then writes the cumulative
    result to a new pickle. """
    output_file = open(f"data/{output_location}", "wb")
    processPickle("data/en_nl_line_pairs.pkl",
                  process=lambda x:pickle.dump(samplingDataset(x, sampleCheck), output_file))

# %%
# Example usage
pickleSample("sample_not_a_sample.pkl", sampleCheck=samplingMethod3)
# Out:
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.

# %%
readPickle("data/sample_not_a_sample.pkl", limiter = 1)
# Out:
# [[['a killer asteroid streaking to our earth at sixty seven miles an hour',
#    'een dodelijke asteroide snelt met 107 200 km u op de aarde af'],
#   ['giant chimney like tower scorching hot, rising from the bottom of the ocean floor',
#    'gloeiend hete, schoorsteenachtige torens die verrijzen vanaf de oceaanbodem'],
#   ['a young man at the sea voyage shook the foundation of the world',
#    "de zeereis van n jongeman die de wereld op z'n kop zette"],
#   ['an expedition back through time into the heart of human ancestry',
#    'we gaan terug in de tijd, op zoek naar de oorsprong van onze voorouders'],
#   ['how species evolved why some species survive and others become extinct',
#    'hoe soorten evolueerden waarom sommige soorten overleefden en andere uitstierven'],
#   ['these are the greatest discoveries in the origin and evolution of life',
#    'dit zijn de grootste ontdekkingen over de oorsprong en evolutie van t leven'],
#   ['life is a game of chance', 'het leven is een kansspel'],
#   ['the odds of surviving or facing extinction are always changing',
#    'de kansen op overleving of uitsterving veranderen steeds'],
#   ['some changes are gradual, result of slow process of nature',
#    'soms gaat dat traag door langzame natuurprocessen'],
#   ['others happened in a blink like one that caused the extinction of the ancient dinosaurs',
#    'soms gaat het snel zoals de verandering waardoor de dinosauriers uitstierven'],
#   ['in 1980, a geologist named walter alvarez was studying rock stratum in mountains north of rome',
#    'in 1980 deed de geoloog walter alvarez onderzoek naar steenlagen ten noorden van rome toen hij wat raars zag:'],
#   ['when he came cross something curious, a thin ancient layer of clay',
#    'een dunne, oeroude kleilaag'],
#   ['so, this clay layer right here marks the boundary between two different geological periods',
#    'dus deze kleilaag hier geeft de scheiding aan tussen twee geologische tijdperken'],
#   ['the clay of layer marks what is known geology as kt boundary',
#    'in de geologie wordt deze kleilaag de kt-grens genoemd'],
#   ['a dramatic turning point in history of earth about sixty five million years ago when the ancient dinosaur mysteriously vanished',
#    'een grote verandering op aarde circa 65 miljoen jaar geleden waarna de dinosauriers op raadselachtige wijze verdwenen'],
#   ['for alvarez, here was the moment of discovery,',
#    'voor alvarez was dit de vondst'],
#   ['analyzing samples of kt boundary, he found the clay contain extremely high levels of iridium',
#    'toen hij monsters uit de kt-grens nam bleek de klei veel iridium te bevatten'],
#   ['and element rare of them on earth, but abundant in space',
#    'dat element is zeldzaam op aarde, maar komt veel voor in t heelal'],
#   ['the answer he concluded was the impact form an asteroid of gigantic proportions',
#    'volgens hem was het de inslag van een reusachtige asteroide geweest'],
#   ['over six miles across, taller than mount everest',
#    'een met een diameter van ruim 9, 5 km'],
#   ['moving at a speed of sixty seven thousand miles an hour',
#    'hij was groter dan de mount everest en bewoog zich voort met een snelheid van 107 200 km u'],
#   ['doctor elisabeth pierazzo is a research scientist in the planetary science institute in tucson arizona',
#    'doctor elisabetta pierazzo is onderzoeker aan het instituut voor planetair onderzoek in tucson'],
#   ['so how much energy is this thing has', 'hoeveel energie had dat ding'],
#   ["ten times world's nuclear arsenal well it was really big",
#    'tien keer het wereldwijde kernwapen arsenaal toen het erg groot was'],
#   ['yes', 'allemaal op een plek'],
#   ['all in one place, all in one point, released in a second',
#    'ja en in een seconde vrijgekomen'],
#   ['so that was humongous amount of energy that was delivered to the earth',
#    'dus de aarde kreeg enorm veel energie te verwerken'],
#   ['the devastation was colossal', 'de verwoesting was reusachtig'],
#   ['the cloud of vaporized rock bring mushroom into the air, blocking the sun',
#    'een paddenstoelwolk van verdampt gesteente blokkeerde de zon'],
#   ['scorching fire balls blasts across the face of the earth the air became choke with poisonous gases and soot',
#    'verschroeiende vuurballen raasden over het aardoppervlak'],
#   ["the only piece of puzzle missing from alvarez's story was proof of the asteroid",
#    "het ontbrekende stukje van alvarez' theorie was het bewijs dat de asteroide er was geweest"],
#   ['if it was as big as he said it was, then it must have left a large crater',
#    'als die zo groot was als hij zei moest de asteroide een grote krater hebben geslagen'],
#   ['finally geologist found one that just happened to be about sixty five million years old the chicxulub crater',
#    'uiteindelijk vonden geologen er een van ongeveer 65 miljoen jaar oud:'],
#   ['of the coast of the yucatan peninsula concentric rings',
#    'concentrische cirkels'],
#   ['this is a meteor crater in arizona', 'dit is meteor crater in arizona'],
#   ['its triggers and explosion greater than twenty million tons of tnt',
#    'er volgde een explosie die groter was dan 20 miljoen ton tnt'],
#   ['and created this, a crater five hundred and fifty feet deep and three quarters of a mile cross',
#    'daarbij ontstond dit:'],
#   ['room enough for twenty football fields and more than two million spectators',
#    'een krater van 168 meter diep met een diameter van 1, 2 kilometer'],
#   ["impressive, isn't",
#    'genoeg ruimte voor 20 footballvelden en ruim 2 000 000 toeschouwers'],
#   ['but remember, the asteroid that caused the kt event was a size of mount everest',
#    'imposant, he maar de kt-asteroide was zo groot als de mount everest'],
#   ['from here to the other side is 16 miles', 'dit is de zuidrand'],
#   ['but even that is not big enough',
#    'van hier naar de overkant is het ruim 25 km'],
#   ['the asteroid that caused the kt extinction blasted a crater 8 times as large',
#    'maar dat is nog te klein'],
#   ['and when the asteroid hit, it went deep as well',
#    'van hier tot de speeltafels in las vegas'],
#   ["it's a long climb here to the bottom of the canyon, about a mile and a quarter",
#    'toen de asteroide insloeg, ging hij ook heel diep'],
#   ['how do scientists know all this the evidence is come from a variety of sources',
#    'daarna liep de krater snel vol hoe weten de geleerden dit'],
#   ['seismic studies revealed that enormous ring-like shape of the crater',
#    'het bewijs komt uit verschillende bronnen'],
#   ['and computer modeling calculated explosion what would take the crater of the chicxulub crater',
#    'computermodellen berekenden de explosie die de chicxulub-krater sloeg'],
#   ['with the opposing scientists offering their own theories',
#    'zijn asteroide-theorie wordt nog steeds betwist door geleerden die allemaal hun eigen theorie hebben'],
#   ["so this has been almost twenty five years it's about yeah",
#    "maar alvarez' theorie is overeind gebleven"],
#   ['the theory is still got, oh, the theory is stronger and stronger',
#    'dus na 25 jaar staat die theorie nog steeds overeind'],
#   ['because scientist form many disciplines have investigated the evidence',
#    'die theorie wordt steeds aannemelijker'],
#   ['form paleontologists to oceanographers, and their research overwhelmingly support what alvarez said the discovery',
#    'allerlei geleerden hebben de aanwijzingen onderzocht: van paleontologen tot oceanografen'],
#   ['that the kt asteroid was responsible for the extinctions of the dinosaurs',
#    'hun onderzoek ondersteunt de ontdekking van alvarez dat de kt-asteroide het uitsterven van de dinosauriers heeft veroorzaakt'],
#   ['today, the extinction of the ancient dinosaurs is taken for granted',
#    'dinosauriers'],
#   ['but for centuries, the world had no inkling that the fable creature ever existed',
#    'tegenwoordig weten we dat de dinosauriers zijn uitgestorven'],
#   ['dinosaurs fossils have been turning up since ancient times',
#    'maar eeuwenlang wist men niet dat deze dieren ooit hadden bestaan'],
#   ['a jaw here, a claw there',
#    'toch doken er sinds de oudheid al fossielen op'],
#   ['but no one has the clue who are what the enormous bones belong to',
#    'hier een kaak, daar een klauw maar niemand wist van wie of wat die reuzenbotten waren geweest'],
#   ['the discovery of the dinosaurs unfolded in a series of small but significant fossil fines',
#    'maar begin 19e eeuw kwam daar verandering in'],
#   ['but with each new fossils discovered came greater new understanding',
#    'de dieren werden vaak beschreven als reuzenversies van levende hagedissen'],
#   ['by 1849, the fossils of nine completely different reptiles had been discovered',
#    'maar na elke nieuwe fossielvondst kwam er meer inzicht'],
#   ['and british anatomist named richard owen created a new scientific category for their identification',
#    'tegen 1849 had men de fossielen van negen verschillende reptielen ontdekt'],
#   ['readopt them dinosaurs, meaning terrible lizard',
#    'de britse anatoom richard owen schiep een nieuwe categorie om de dieren te identificeren'],
#   ['to the world of the eighteenths hundreds, the discovery was revolutionary',
#    'hij noemde ze dinosauriers dat betekent: verschrikkelijke hagedissen'],
#   ['it helped give birth to the science of paleontology',
#    'in de 19e eeuw was de ontdekking van dinosauriers revolutionair'],
#   ['and because this creature are obvious extinct, the discovery stirred the debate about the history of life on earth',
#    'zo ontstond de wetenschappelijke discipline paleontologie'],
#   ['for hundred fifty million years, dinosaurs dominated life on earth',
#    'de ontdekking van deze uitgestorven dieren zorgde voor discussies over de geschiedenis van het leven op aarde'],
#   ["see, the ancient dinosaurs hadn't die out you have to figure we wouldn't be here",
#    'en 65 miljoen jaar later zijn wij er'],
#   ['so, how do we get here in the first place where on earth did life emerge',
#    "als de dino's niet waren uitgestorven, zouden wij er niet zijn geweest"],
#   ['our next great discovery offered a compelling possibility for the kitchen of creation',
#    'hoe zijn wij hier dan gekomen waar is t leven op aarde ontstaan'],
#   ['but the volcano here in yellow stone is a little bit different',
#    'maar de vulkaan in yellowstone is anders'],
#   ['we are standing on it', 'we staan erop'],
#   ["nearly all of yellow stone's two million acres sit on top of an enormous underground super volcano, forty miles wild",
#    'bijna heel yellowstone ligt op een grote, ondergrondse supervulkaan met een diameter van 64 km'],
#   ['its crater is here, just below the surface',
#    'de krater ligt onder de oppervlakte'],
#   ['and down there is molten rock, the source of intense heat, the power of old faithful',
#    'ondergronds zit gesmolten gesteente: een hittebron die old faithful laat spuiten'],
#   ['and the simmering volcano fuels the hot spring here as well',
#    'de zachtjes kokende vulkaan verwarmt ook de bronnen hier'],
#   ['a crater that some of the primitive microbes on the planet',
#    'een bakermat voor een paar van de primitiefste microben op aarde'],
#   ['bain in the primitivesoup, incubated by volcanic steam the organism flourished',
#    'badend in een oersoep en bevrucht door vulkanische stoom tieren deze organismen welig'],
#   ['and our next great discovery demonstrated',
#    'onze volgende ontdekking laat zien hoe dat kan zijn gebeurd'],
#   ['how it might have happened',
#    'het scheppen van de juiste omstandigheden voor leven'],
#   ['water but no oxygen in the air', 'water, maar geen zuurstof in de lucht'],
#   ['an atmosphere teaming with mixed of gases',
#    'een atmosfeer die uit talloze gassen bestaat'],
#   ['sulfur and methane, hydrogen and ammonia',
#    'zwavel en methaan, waterstof en ammoniak'],
#   ['miller started by filling in an enclosed container with water, then he added the mix of gases',
#    'miller begon met een dichte bak water en voegde daar t gasmengsel aan toe'],
#   ['to replicate the effect of the sun, he heated the mixture with bunsen burner',
#    'om de zon na te bootsen, verhitte hij het mengsel met een bunsenbrander'],
#   ['to simulate lightning bolts, he jolted the concoction with bursts of electricity',
#    'om bliksems na te bootsen, gaf hij het mengsel stroomschokken'],
#   ['he waited several days before analyzing the liquid in the container',
#    'na een paar dagen analyseerde hij de vloeistof in de bak'],
#   ['the result was astonishing', 'de resultaten waren verbazend'],
#   ['the liquid contained organic compounds, a central building block for creating proteins',
#    'de vloeistof bevatte organische verbindingen:'],
#   ['which play a vital role in the biochemical spark that starts life',
#    'bouwstoffen om eiwitten te vormen die een belangrijke rol spelen bij het ontstaan van leven'],
#   ['so what did stanley miller discover', 'wat had miller ontdekt'],
#   ["while he didn't create life in the lab,",
#    'hij had geen leven in t lab geschapen'],
#   ["he created the potential for life and that's significant",
#    'hij schiep de kans op leven'],
#   ['it meant with the right materials and right conditions, life could happen anywhere',
#    'dat is belangrijk onder de juiste omstandigheden bleek leven overal te kunnen ontstaan'],
#   ["however there's no shortage of the theories",
#    'toch is er aan theorieen geen gebrek'],
#   ['with our next great discovery',
#    'misschien ligt t antwoord op de zee bodem bij onze volgende ontdekking'],
#   ['in 1977, a deep sea submarine descended over 8000 feet',
#    'in 1977 dook een diepzee-duikboot tot ruim 2438 meter diep'],
#   ['its mission to investigate hydrothermal activity on the ocean floor',
#    'zijn taak: hydrothermale activiteiten op de zeebodem onderzoeken'],
#   ['marine explorer robert ballard was on board',
#    'oceanograaf robert ballard was aan boord'],
#   ["he detected a dramatic change of the ocean's temperature we were not expecting what we found",
#    'hij ontdekte een temperatuurwisseling in de oceaan'],
#   ['we are expecting to find water', 'dit hadden we niet verwacht'],
#   ['and we had a camera inside vehicle but it was, just taking pictures',
#    'we verwachtten water te vinden'],
#   ["we didn't know we have it came back",
#    "de boordcamera maakte foto's, maar die konden we pas later bekijken"],
#   ['probably one of the biggest biological discovery ever make on earth was made that day',
#    'we deden die dag een van de grootste biologische ontdekkingen ter wereld'],
#   ['ballard and his team were the first to see it, face to face hydrothermal vents',
#    "ballard en z'n team waren de eersten die er oog in oog mee stonden:"],
#   ['and mass chimney like structures, several stories high',
#    'hydrothermale bronnen enorme schoorsteenachtige structuren van ettelijke etages hoog'],
#   ['spewing hot water geyserblack with mineral and nutrients',
#    'geisers die heet water spuiten dat zwart ziet van de mineralen en voedingsstoffen'],
#   ['and then the astonishing sight',
#    'de temperatuur bij deze bronnen bedroeg 404 graden celsius'],
#   ['life thriving without sunlight, a biological community never seen before',
#    'en toen zagen ze iets wonderlijks leven dat welig tierde zonder zonlicht'],
#   ['an exotic garden of marine life',
#    'een biologische gemeenschap die nog nooit was aanschouwd'],
#   ['species without eyes', 'een exotische tuin van marien leven'],
#   ['and when you cut them, they bled human like blood',
#    'als je die sneed, zag je mensachtig bloed'],
#   ['and then to find this extremely unusual creatures living in this oasis',
#    "dat was heel griezelig het is raar als je op zulke ongewone wezens stuit die in zo'n oase leven"],
#   ['we opened up it first and, oh, since we open it up, it s stonk',
#    'toen we na afloop een schelp ontleedden'],
#   ["it's full of hydrogen and sulfur it's horrible smell, raw eggs",
#    'kwam er eerst een stank uit'],
#   ['yes, and when we look, it did, it looked like beef',
#    'waterstofsulfide rotte eieren'],
#   ["was red, bright red, and it didn't have anatomy clam, those like",
#    'toen we de schelp vanbinnen bekeken, leek die op rundvlees alles was rood'],
#   ['what happened to the clam, someone is taken over its body and something was bacteria',
#    'anatomisch was het geen schelpdier waar was dat gebleven'],
#   ['a tiny bacteria that had figured out over years of time',
#    "iets had z'n lichaam overgenomen en dat iets was een bacterie"],
#   ['how to duplicate photosynthesize in the dark chemically through processes we know chemosynthesis',
#    'een kleine bacterie die in de loop der tijd had geleerd om fotosynthese in het donker chemisch te reproduceren'],
#   ['that was the discovery', 'dat proces heet chemosynthese'],
#   ['that there was another life system on earth that did not go by the book that you and i read',
#    'dat was de ontdekking'],
#   ["it's bacteria we now think are the largest mass of living things on earth",
#    'dat is echt heel andere koek nou en of'],
#   ['and there are in the rocks, everywhere, under the ocean',
#    'we denken nu dat die bacterien de grootste massa van levende dingen op aarde zijn'],
#   ['if you add all the people and all the living things on land',
#    'ze zitten in de stenen in de hele bergketen onder de zee'],
#   ['it you think that the insects rule the world',
#    'die bacterien hebben meer biomassa'],
#   ["wrong, it's bacteria so where are these vents all over the earth",
#    'ooit dachten we dat insecten de wereld domineren, maar het zijn die bacterien'],
#   ['imagine a baseball that was seam on it', 'waar zijn die bronnen'],
#   ['that seem began beneath the polar icecaps, goes down through the atlantic',
#    'overal ter wereld stel je de naad van n honkbal voor'],
#   ['into the indian ocean, across the pacific ocean as a largest feature on earth, the mid ocean ridge',
#    'die naad loopt via de polen naar de atlantische, indische en stille oceaan'],
#   ["and it's underlying by literally ten thousands of magma chambers",
#    'met 67 592 km is de midoceanische rug het grootste ding op aarde'],
#   ["is that where life began well that's what people are now thinking",
#    'en daaronder liggen tienduizenden magmakamers'],
#   ['the biology books that we were reading have now been thrown away',
#    'is het leven bij die bronnen ontstaan'],
#   ['and when i grown i have learned everything on surface',
#    'dat denkt men nu de biologieboeken die wij lazen zijn weggegooid'],
#   ['yes you have this soup in the lightning heated and new formed amino acid and things like that',
#    'in mijn tijd was alles aan land'],
#   ['but now, we think that the hydrothermal vents may have been the site of life on earth',
#    'je had de oersoep en door de bliksem zouden dan aminozuren ontstaan'],
#   ['it also given us a new prospecting to, for searching for',
#    'nu denken we dat leven wellicht bij hydrothermale bronnen is ontstaan'],
#   ['elsewhere with our solar system we now are looking at the moon of jupiter called europe',
#    'het is tevens een hulpmiddel bij het zoeken naar leven binnen ons zonnestelsel'],
#   ['which we think has an ocean, we think it has underwater volcanoes and should be life on there',
#    'nu onderzoeken we n maan van jupiter: europa'],
#   ['the question is how smart the clams',
#    'we denken dat daar een oceaan is met onderzeese vulkanen'],
#   ['did hydrothermal vents give birth to the first primitive microbe on earth',
#    'daar zou leven moeten zijn de vraag is: hoe slim zijn hun schelpdieren'],
#   ['perhaps but one thing is certain,',
#    'zorgden hydrothermale bronnen voor het eerste microbiele leven op aarde'],
#   ['their discovery challenged the long beliefs about the conditions necessary for creating life',
#    'misschien wel'],
#   ['and once life happened, there was no stopping',
#    'in elk geval wordt er sinds hun ontdekking anders gedacht over de voorwaarden waarbij leven kan ontstaan'],
#   ['was doing some field work in british columbia he and his wife were riding along a mountain trail',
#    'zijn vrouw en hij reden op n bergpad toen een muilezel een hoefijzer verloor'],
#   ['the story goes; one of their mules lost a shoe',
#    'toen walcott t hoefijzer wilde pakken, zag hij een stuk schalie: een steen'],
#   ['and when walcott bent down and retrieved it, he came across a piece of shale',
#    'het leek een gewone steen, maar in de zon schitterde hij'],
#   ['a rock, and it was ordinary looking at first when the sunlight heated it, it shimmered like silver',
#    'toen hij beter keek, zag hij een fossiel'],
#   ['they came across something that no one has ever seen before',
#    'een grote afzetting'],
#   ['wolcott called his discovery the burgess shale',
#    'walcott noemde zijn ontdekking de burgess shale'],
#   ['douglas erwin is curator of the smithsonian national museum of natural history',
#    'douglas erwin is curator van het smithsonian museum of natural history van dinosauriers vind je de botten ja'],
#   ['the burgess shale we find all of these in pieces',
#    'dit is de de geheime kamer'],
#   ['for under i take you into the secret room', 'de collectie'],
#   ['yes, this is a secret room',
#    'in deze kamer bewaren we de belangrijkste fossielen'],
#   ['how action seen and this is a general keep a lot of important fossils traveled by',
#    'trilobieten, ammonieten en de burgess shale'],
#   ['trilobite, ammonite and burgess shale',
#    'kijk, dit wilde ik je laten zien'],
#   ["that's what i want to show you", 'dit is er een in twee delen'],
#   ['we have the cart part here', 'oorspronkelijk was het een steen'],
#   ['so this is the aysheaia, aysheaia is a form of worm',
#    'dat is een fluweelworm we weten niet wanneer ze aan land zijn gekomen'],
#   ['when they moved from the ocean to land,', 'kijk, hier zitten pootjes'],
#   ['we have no idea, but you can see the legs, like, or something like the antenna',
#    'en daar zitten voelsprieten'],
#   ['and if you move that back and forth, you can see shinny beats at the end of the legs',
#    'als je dit heen en weer beweegt kun je glimmende stukjes zien achter bij hun pootjes dat zijn de teennagels'],
#   ['of course they are the fossils that wolcott discovered were remarkably preserved',
#    'de fossielen van walcott bleken goed bewaard te zijn'],
#   ['a vivid snapshot of the time when ancient life on earth was dominated by curious underwater creatures',
#    'een kijkje in n tijd dat het leven op aarde werd gedomineerd door zonderlinge onderwaterwezens'],
#   ['this is a bigger predator of the cambrian,',
#    'in china waren ze wel 90 cm tot 180 cm lang'],
#   ['the mouth actually opened up, and as those rotated and close, it crunched the carapace',
#    'de mond ging open en de monddelen raspten zich daarna door de schelp heen:'],
#   ['like the beak of an octopus',
#    'als de snavel van een octopus ja dit is opabinia'],
#   ['yeah, this is an opabinia', 'opabinia'],
#   ['opabinia', 'ja, een van mijn favorieten'],
#   ["it's one of my favorites, probably cause it's a such weird animal",
#    "vast omdat het zo'n raar dier is"],
#   ["it's just like someone had made it up",
#    'alsof iemand het heeft verzonnen het is net een chinese menukaart'],
#   ["but it's something we can't compare with today five eyes, claws, claws",
#    'nu vind je geen dieren meer met vijf ogen en een klauw zoals opabinia'],
#   ['the site of the burgess shale was created by a sudden and violent active nature',
#    'de burgess shale is ontstaan door een plotselinge natuurramp'],
#   ['underwater mudflow stroke fast',
#    'onderzeese modderstromen sloegen snel toe'],
#   ['a landslide of settlement crashed down, burring everything as it passed',
#    'een landverschuiving van sedimenten begroef alles op haar pad'],
#   ['they were remained in tomb for hundreds of millions of years',
#    'wat eronder verdween, bleef honderden miljoenen jaren bedolven'],
#   ['nothing to help to complicated',
#    'er was veel microbieel slijm, maar verder niks ingewikkelds'],
#   ['only began to have first animal diversifying of this whole wide arrange of things',
#    'daarna pas gaan de eerste dieren varieren en krijg je het hele scala'],
#   ['so far, the discovery of the burgess shale',
#    'tot dusver zijn in de burgess shale circa 170 soorten zeedieren ontdekt'],
#   ['an astonishing explosion of multicell body types',
#    'een verbazende explosie van meercelligen'],
#   ['astonishing because for billions of years, the earth had been dominated by one celled creatures',
#    'verbazend, omdat in de miljarden jaren daarvoor eencelligen dominant waren'],
#   ['the burgess shale is a wonderful window into this big bang of animal life',
#    'de burgess shale is een kijkje in de oerknal van dierenleven'],
#   ['better than play with the dinosaurs,',
#    'dit is veel leuker dan dinosauriers'],
#   ["why do you think it's better than play with dinosaur", 'waarom'],
#   ['well, these are much more fascinating', 'deze dieren zijn veel boeiender'],
#   ['and dinosaurs are not very long until that they turned into birds',
#    'dinosauriers zijn vrij recent en ze evolueerden tot vogels'],
#   ["yes, they're soft", 'blijf dan op kantoor'],
#   ["even steven spielberg and lucas wouldn't come up with opabinia",
#    'spielberg en lucas hadden geen opabinia kunnen bedenken'],
#   ["that's why it's so cool", 'daarom zijn ze zo cool'],
#   ['we never know the exist without the burgess shale',
#    'zonder de burgess shale waren ze onbekend gebleven'],
#   ['not all the great discovery started with uncovering a piece of physical evidence',
#    'niet alle ontdekkingen beginnen met een tastbare aanwijzing'],
#   ["it wasn't always a place to explore or fossil to find",
#    'er was niet altijd een onderzoeksplek of een makkelijk vindbaar fossiel'],
#   ['our next great discovery started with an idea',
#    'onze volgende ontdekking begon met een idee'],
#   ['it could disappear and that sort of was a slight show',
#    'het ging vooral om de indeling en naamgeving van al die pas ontdekte planten en dieren'],
#   ['the main attraction was the classification of the naming of all these newly discovered types of plants and animals',
#    'er was nog geen systeem om alles wat leeft in te delen en te benoemen'],
#   ["now, back then, they didn't really have a good system to the classification and naming of living things",
#    'als een geleerde een nieuwe plant-of diersoort ontdekte, verzon hij n naam:'],
#   ['so, scientists might find a new type of living thing, and then just named whatever they wished',
#    'een onhandige latijnse naam'],
#   ['scientists at the time thought it was genius',
#    'linnaeus noemde het zelf:'],
#   ['but linneus had the self-called greatest achievement in science',
#    "de grootse prestatie in de wetenschap linneaus' systeem is nu nog in gebruik"],
#   ["well we still use a lot of linneus's tradition today",
#    'zo benoemen we dingen naar geslacht en soort: het binomiale systeem'],
#   ['including naming things by their genus and species the binomial system',
#    'wij heten bijvoorbeeld nog steeds homo sapiens'],
#   ['you and i are still called homo sapiens for example',
#    "linnaeus' systeem was gebaseerd op de geslachtsorganen van planten"],
#   ["so, then he's named a particular plant sigas bekia cause it was a stinky weed",
#    'dus noemde linnaeus een bepaald soort plant siegesbeckia omdat het een stinkend onkruid was'],
#   ["today, the science of classify species has expanded beyond the linneus's system",
#    "tegenwoordig gaat de indeling van soorten verder dan linnaeus' systeem"],
#   ['with information from deep dna sequencing and analysis of miraculous data scientist had new understanding of relationships among species',
#    'met informatie van dna en analyse van moleculaire gegevens hebben geleerden een nieuw begrip van de relatie tussen de soorten'],
#   ['as a result, modern classification systems advocate categorizing species based on how they evolved',
#    'daarom delen moderne systemen soorten in op basis van hun evolutie en hun plek in de stamboom des levens'],
#   ['but when it was, many would consider it was the greatest discovery in the history of the world',
#    'maar toen het zover was, vonden velen het de grootste ontdekking ooit'],
#   ['there was no anesthetic',
#    'jonge studenten geneeskunde moesten toekijken om het te leren'],
#   ['darwin was hired as a naturalist to board the british amoulty hms beagle',
#    'dit schip ging op expeditie om overal ter wereld kustwateren in kaart te brengen'],
#   ['which embarked on expedition to survey and map coast water around the world',
#    'de beagle was vijf jaar op zee en voor darwin leek het n eeuwigheid'],
#   ['he shared a small cabin with the captain, with whom he has several disagreements, including the story of creation',
#    'hij deelde n hut met de kapitein met wie hij vaak discussieerde over t scheppingsverhaal darwin'],
#   ["darwin while the captain held the bible's account of creation",
#    'de kapitein geloofde in de schepping, maar darwin dacht dat de aarde langzaam was veranderd in miljoenen jaren'],
#   ['darwin believed that the earth had changed slowly over millions of years',
#    'dit meningsverschil zou darwin de rest van zijn leven achtervolgen'],
#   ['it was a debate that followed darwin for the rest of his life',
#    'bekostigde de britse regering dit'],
#   ["the british government paid for this no actually darwin's father paid for his voyage",
#    'darwins vader betaalde de reis en darwins assistent die hielp met het villen van de specimens'],
#   ['and also paid for his assistant to come with darwin and helped him',
#    'en met t maken en verzenden van pakketten'],
#   ['skin the specimen and prepare the crates for shipment',
#    "hij werkte op het achterdek waar hij al z'n soorten had ja, ongeveer zoiets als dit"],
#   ['he worked at little poor deck where he had all his specimens just about something like this',
#    'de beagle deed havens aan van australie tot zuid-amerika'],
#   ['the beagles made stop over ports of australia to south america',
#    'inclusief n verblijf van 36 dagen op de galapagos eilanden'],
#   ['and darwin made the most of it',
#    'hij maakte uitgebreide beschrijvingen van de inheemse flora en fauna'],
#   ['he recorded the extensive observation about the indigenous plants and wild lives',
#    'hij verzamelde duizenden specimens voor onderzoek'],
#   ['he collected preserved thousands of specimens for study for years after the voyage,',
#    'jaren na de reis kon darwin zich zijn observaties aan boord van de beagle nog herinneren'],
#   ['darwin recorded the observations he made while aboard the beagle',
#    "in 1837, enkele jaren na z'n terugkomst van de galapagos eilanden kijkt hij z'n eerste notitieboek in"],
#   ['he opened his first species notebook and asked himself a question',
#    'en dan stelt hij zich een erg ambitieuze vraag voor iemand van eind twintig:'],
#   ['what are the laws of life',
#    'ja, hij zocht wetten die golden in de natuurlijke wereld'],
#   ["is this darwin's whole point it was darwin's whole point",
#    'zoals fysici en chemici die hadden gevonden in de anorganische natuur'],
#   ['darwin searched to understand the laws of nature took shape as he studied the animals on the galapagos islands',
#    'hij vond vooral de fysieke verschillen binnen een soort interessant'],
#   ['of special interests to him, the physical differences was within a certain species',
#    'vinken op de galapagos eilanden hadden verschillende snavels'],
#   ['for example, the finches on the galapagos islands had different shape of beaks',
#    'die verschilden afhankelijk van de leefomgeving van de vinken'],
#   ['they varied according to the environments where the finches live',
#    'sommige hadden harde, stompe snavels om krabben mee te doorboren'],
#   ['some had beaks that were hard and blunt, idea for hammering open crab shells',
#    'andere vinken hadden spitse snavels om tussen stenen te pikken'],
#   ['with this simple yet powerful insight, history was made',
#    'darwin ontdekte het principe achter evolutie:'],
#   ['darwin discovered the mechanism that made evolution work',
#    'het proces van natuurlijke selectie'],
#   ['the process of natural selection',
#    'darwin was niet de eerste die dit bedacht'],
#   ["darwin isn't the first guy really come up with this right",
#    'wat maakte zijn invalshoek nou zo bijzonder'],
#   ['what was his special or particular insight',
#    'hij was de eerste die het principe van natuurlijke selectie bedacht'],
#   ["he was the first to come up with the specific mechanism, that's natural selection",
#    'hij ging als eerste uit van processen die miljoenen jaren duurden'],
#   ['which were related to all the living things',
#    'de geneticus dobzhansky zei ooit:'],
#   ['the great geneticist dobzhansky once said',
#    'niets binnen de biologie is logisch zonder evolutie'],
#   ['nothing in biology makes sense without evolution',
#    'de biologie van tegenwoordig is evolutionaire biologie'],
#   ['how we got here, what kind of creature we are',
#    'hoe zijn we verwant aan alles in de natuur'],
#   ['how we were related to everything in the nature',
#    'we maken allemaal deel uit van de stamboom des levens'],
#   ['it has been established we are all part of wonderful great tree of life',
#    'onze afstamming, ons dna, verbindt ons met alles wat leeft op aarde'],
#   ['plug into a blood line to a dna that links us to every living thing on earth',
#    'en dat is geen metafoor dat is letterlijk bedoeld'],
#   ["that's not a matter of foragle that's literal",
#    "waarom heeft darwin z'n ideeen pas na 20 jaar gepubliceerd"],
#   ['he knew there may be a religious storm protest',
#    'zijn vrouw was niet blij dat hij dingen schreef die tegen de bijbel indruisten'],
#   ['his own wife was not happy that he was going to write things that were incompatible with the bible',
#    'als jonggehuwde schreef ze hem:'],
#   ['she wrote him a letter when they first marriage, saying,',
#    'hopelijk leidt je wetenschap er niet toe dat we in de eeuwigheid op verschillende plekken zullen zijn'],
#   ['i hope that your science will not lead us to spend the eternity to very different places',
#    'daar maakte ze zich echt zorgen over'],
#   ['and she was seriously concerned about this',
#    'en hij wilde een massa onweerlegbare bewijzen vergaren'],
#   ['his book, origins of species is considered one of the greatest books ever written',
#    'zijn boek de oorsprong der soorten wordt gezien als n weergaloos werk'],
#   ['people are talking about the theory of evolution, right',
#    'met betrekking tot de evolutietheorie was het toch darwin die zei:'],
#   ["but darwin was the guy that said that there isn't any absolute truth there",
#    'er bestaat geen absolute waarheid'],
#   ['darwin being one of the first thinkers try to tell us that science is provisional',
#    'darwin zei daarmee dat wetenschap voorlopig en veranderlijk is wat bedoelt u met voorlopig'],
#   ['it changes', 'de waarheid van nu'],
#   ['and you have to get a new theory',
#    'het is geen eeuwige waarheid het is voorlopig'],
#   ['so, that is not an eternal truth', 'het verandert'],
#   ["it's a provisional truth it changes",
#    'hij wilde niet dat evolutie een dogma of geloof zou worden'],
#   ["and he didn't want evolution to be accepted an the dogma or a creed",
#    'hij zou hebben gezegd:'],
#   ['he would be the first to say throw out if you got something better',
#    'weg ermee als je wat beters hebt maar dat hebben we niet juist'],
#   ['and motivated scientist of many disciplines to begin exploring the theory',
#    'zeggen dat we van apen afstammen is een ding maar het bewijzen is wat anders'],
#   ["he named her lucy after the beetle's song lucy in the sky with diamonds",
#    'ook al waren het slechts resten, toch gaf lucy toch geheimen prijs'],
#   ['despite of her fragment remains, lucy has remarkable secrets to share about her life',
#    'past dit'],
#   ['doctor ken mowbray is an anthropologist within the america museum of natural history',
#    'lucy schudde de stamboom flink op'],
#   ['well, lucy really shook up the family of tree sort of speak',
#    'waarom was ze zo belangrijk om heel veel redenen'],
#   ['why was she such a big deal',
#    'ten eerste was haar skelet voor 40 procent compleet'],
#   ['she was a big deal for many reasons', 'noemen jullie 40 procent compleet'],
#   ['first of all, her skeleton was 40 percent complete',
#    'voor een fossiel zijn dat veel beenderen voor een individu'],
#   ["40 percent complete to you guys you know in fossil terms that's a lot for a fossil bones for individual",
#    'wat haar echt heel belangrijk maakt is dat we aannemen dat ze op twee benen liep'],
#   ['something even more important that makes it really significant is that we believe that she was bipedal',
#    "ik heb hier een afgietsel van de linkerkant van lucy's bekken"],
#   ['have a of the cast here of the pelvis of the lucy, the left side',
#    'het bekken bevindt zich hier in ons lichaam het is kort en breed'],
#   ["the pelvis is like this in the human body, it's short and it's broad",
#    "bij chimpansees, gorilla's of orang oetans is het bekken smal en groot"],
#   ['if you look at chimpanzee, gorilla or orangutan their blades are really narrow and really tall',
#    "lucy's bekken breidt zich naar buiten uit, net als het onze"],
#   ['the blade of lucy and like ours is stand out really',
#    'zo wordt het gewicht verdeeld als je van plan bent op twee benen te gaan lopen'],
#   ['this allows the transference of weight if you were going to walk onto limbs',
#    'door dit bekken nemen we aan dat lucy door het landschap liep als een tweevoeter'],
#   ['so, from this pelvis lonely, think that, lucy move on the landscape as a bipedal or biped',
#    'zoals jij en ik ja, eigenlijk liep ze zoals wij'],
#   ['connecting apes with the first humans',
#    'sommige antropologen zoals mowbray geloven dat de ontbrekende schakel een mythe is'],
#   ['but some anthropologist like doctor mombray believed that the missing link is a myth',
#    'heel lang dacht men dat er een schakel was tussen chimpansees en mensen'],
#   ['now, for long time, people thought there was a link between chimpanzees and humans',
#    'als je ze ziet, lijkt dat logisch, maar het ligt niet zo simpel, he nee'],
#   ["to have a better understanding that there wasn't a linear progression of evolution, especially with human",
#    'vooral bij mensen er was veel meer variatie'],
#   ['that was much more diversified',
#    'door lucy en latere fossielvondsten weten we dat de stamboom des levens veel meer op een struik lijkt'],
#   ['with lucy and subsequent fossil fines, we really know that this tree of life is much more like a bush',
#    'er wordt veel geexperimenteerd zonder dat t wat oplevert'],
#   ["there's a lot experimentations going on and a lot of dead ends",
#    'de laetoli-voetafdrukken'],
#   ['a paired of fossilized footprints, old enough and small enough',
#    'een stel fossiele voetafdrukken die oud en klein genoeg waren om door twee hominiden te zijn gemaakt hominiden zoals lucy'],
#   ['to have been made by two hominids, much like lucy',
#    'het belang ervan is dat ze 3, 6 miljoen jaar oud zijn'],
#   ['those are the oldest human ancestors footprints that we have we know of today',
#    'het zijn de oudste voetafdrukken van menselijke voorouders die we hebben nog belangrijker is dat ze gedrag vastleggen'],
#   ['more importantly i think, it records behavior',
#    'die voetafdrukken vertellen ons dat ze op twee benen liepen'],
#   ['their footprints let us know they were walking bipedally',
#    'er waren geen sporen van vinger-of knokkelafdrukken bij de voetafdrukken'],
#   ['they were no fingerprints, there were no knuckle marks around, the imprints of their feet',
#    'bovendien weten we dat ze in groepen leefden ze waren sociaal'],
#   ['and on top of that, we know that they were in groups, they were social',
#    'ze liepen niet alleen'],
#   ["they weren't just walking by themselves",
#    'de vondst van de laetoli-voetafdrukken was mogelijk door een reeks natuur rampen van 3, 7 miljoen jaar geleden'],
#   ['a volcano erupted, covering the landscape with the thin layer of ash',
#    'na een vulkaaneruptie werd het land onder een dunne aslaag bedekt'],
#   ['as rain fell, the ash became thick like wet cement',
#    'toen het daarna ging regenen, werd de as dik als nat cement'],
#   ['and soon was covered by animal tracks', 'vogels'],
#   ['birds', 'een konijn'],
#   ['a rabbit and then the footprints of two hominids',
#    'en dan de voetafdrukken van twee hominiden'],
#   ['eventually another volcanic eruption blanketed the spot with more ash,',
#    'uiteindelijk bedekte een 2e vulkaan eruptie de plek opnieuw met as dit aslaagje conserveerde de afdrukken terwijl ze uithardden'],
#   ['a protective layer that preserved the prints they hard and remained hidden until mary leakey revealed them to the world',
#    'ze bleven verborgen tot mary leakey ze aan de wereld onthulde'],
#   ['toumai', 'de toumai-schedel'],
#   ['they nicknamed toumai, meaning hope of life',
#    'de schedel had bijzondere kenmerken'],
#   ['the skull revealed features never seen before an ape like cranium',
#    'een hersenschedel als van een aap, maar met mensachtige tanden'],
#   ['but with teeth far more humanlike',
#    'met n leeftijd van 7 miljoen jaar is toumai het oudste hominide fossiel tot nu toe:'],
#   ['more than twice as old as lucy, raising significant new questions about the diversity of life among ancient hominids',
#    'dit roept nieuwe vragen op over de diversiteit onder vroege hominiden'],
#   ["so, what's the significance of the skull for chad, toumai",
#    'wat is het belang van de schedel uit tsjaad toumai'],
#   ['its tell us couple of different things',
#    'hij laat zien dat er veel diversiteit is binnen de fossiele hominide vondsten'],
#   ['what is it mean to you be a hominid', 'wat is een hominide volgens jou'],
#   ['well, i look it being a hominid in two different ways',
#    'ik bekijk het op twee manieren'],
#   ["hominid's lack the ability to remain bored",
#    'hominiden zijn niet in staat om zich langdurig te vervelen'],
#   ['there were a group of primate out there that they had no ability just sit there and doing nothing',
#    'er was ooit n groep primaten die gewoon niet in staat was om te zitten niksen'],
#   ['and this coupled with operate perpetual bypetalism',
#    'dit in combinatie met tweevoetigheid is volgens mij een hominide'],
#   ['this is what a hominid means to me bipedal and unable to remain bored yes',
#    'tweevoetig, en niet in staat om zich langdurig te vervelen'],
#   ["i'm a hominid doga", 'ik ben een hominide, verdorie reken maar'],
#   ['oh absolutely, we are hominids', 'wij zijn hominiden'],
#   ["it's a fact of life on earth", 'op aarde hoort uitsterven bij het leven'],
#   ['extinction happens',
#    'uiteindelijk eindigt elke soort als de dinosauriers'],
#   ['eventually every species goes away of ancient dinosaurs',
#    'waarom zijn wij er dan nog'],
#   ["we've our shared damn luck so far, species that face catastrophe of a speeding asteroid",
#    'onze soort heeft nog geen ramp beleefd zoals een inslaande asteroide'],
#   ['life, like a roulette is a game of chance',
#    'leven is een kansspel, net als roulette'],
#   ['but since the greatest discoveries we just explored',
#    'door de net besproken ontdekkingen stijgt onze overlevingskans misschien'],
#   ['everything moves, everything orbits', 'alles beweegt, alles draait'],
#   ['it is how we are born', 'zo komen wij ter wereld'],
#   ['the sun, the moon, the planets and the stars watch',
#    'de zon, de maan, de planeten en de sterren kijken toe'],
#   ['we are at the centre', 'en wij staan in het midden'],
#   ['our place', 'onze plaats'],
#   ['but, nicolaus copernicus came and said that the sun stood at the centre and that we moved around it',
#    'maar nicolaas copernicus kwam en stelde dat de zon in het midden staat, en dat wij om haar heen draaien'],
#   ['just like the other planets', 'net als de andere planeten'],
#   ['an earth that moves', 'een aarde die beweegt'],
#   ["but can't we see or feel that",
#    'maar daar zien en voelen we toch niets van'],
#   ['that was 1543', 'dat was 1543'],
#   ['galileo made a telescope and pointed it at the sky in 1610',
#    'galileo maakte een kijker en richtte die in 1610 voor het eerst naar de sterrenhemel'],
#   ['later christiaan huygens and dominique cassini discovered moons around planet saturn',
#    'later ontdekten christiaan huygens en dominique casini ook manen rond de planeet saturnus'],
#   ['everything seemed to orbit something', 'alles draait ergens omheen'],
#   ['could it be true', 'zou het dan toch waar zijn'],
#   ['johannes kepler described these movements isaac newton caught them',
#    'johannes kepler beschreef die bewegingen en isaac newton ving ze'],
#   ['from apple to planet: everything obeyed his laws',
#    'van appel lol planeet: alles volgde zijn wellen'],
#   ['and the stars that we see', 'en de sterren die wij zien'],
#   ['what about that band of nebulous light, the milky way',
#    'die band van nevelachtig licht, de melkweg'],
#   ['different cultures had given it different interpretations',
#    'verschillende culturen hadden er een speciale betekenis aan gegeven:'],
#   ['it turned out that the milky way is made of stars:',
#    'het bleek dat die melkweg ook bestaat uit sterren:'],
#   ['hundreds, thousands millions of stars',
#    'honderden, duizenden, miljoenen sterren'],
#   ['and then we discovered the nebulae',
#    'en toen ontdekten we dat er ook neveltjes waren'],
#   ['some were spiral shaped, other oval or irregular',
#    'sommige met een spiraalvorm, andere ovaal of onregelmatig'],
#   ['where did they belong to', 'waar zouden die dan bij horen'],
#   ['how did everything fit together', 'hoe past alles in elkaar'],
#   ['we, the stars, the milky way, the nebulae',
#    'wij, de sterren, de melkweg, de nevels'],
#   ['in the middle of the 19th century we knew that the stars were in fact like the sun',
#    'midden negentiende eeuw wisten we wel, dat al die puntjes van licht eigenlijk zonnen zijn'],
#   ['that they must be very far away', 'dat ze heel ver weg moeten staan'],
#   ['and that the sun was very close by',
#    'dat de zon een ster is die heel dichtbij staat'],
#   ['and that was the universe, a collection of stars',
#    'en dat was het heelal, die verzameling van sterren'],
#   ['and our place in all that', 'en onze plaats in dat alles'],
#   ['caused a big change in the field of astronomical observations',
#    'die omwenteling, dat was de introductie van de fotografie'],
#   ["this catalogue of northern stars was also called a durchmusterung' a german word for survey",
#    "zo'n inventaris noemde men dan een durchmusterung' dat is het duitse woord voor inventaris, laten we maar zeggen"],
#   ['with the introduction of astronomical photography an astronomer at the southern hemisphere said:',
#    "toen de fotografie z'n intrede had gedaan, was er bovendien op het zuidelijk halfrond iemand die zei:"],
#   ['so, there is a place where the photographic plate is put, about here',
#    "en daarom is zo'n kijker zo gebouwd, dat hij een gedeelte heeft waar de fotografische plaat zich bevindt"],
#   ['that is the focal plane of the telescope',
#    'dat is dan ongeveer in dit vlak, het brandvlak van het objectief van die kijker'],
#   ['parallel to it, there is another telescope, here below',
#    'en parallel daaraan is een andere kijker, waardoor je een oogje houdt op wat hij ziet aan de hemel'],
#   ['that could take several minutes or even longer',
#    "en dan heb je dus een paar minuten, of misschien wel langer, nodig om zo'n opname te maken"],
#   ['em started this big project to photograph the entire southern sky',
#    'gill is dus begonnen met dat grote project, van het opnemen van al die platen van de zuidelijke hemel'],
#   ['but he did not immediately think about measuring all these plates',
#    'hij heeft niet onmiddellijk daar bij gezegd: nou, dan ga ik die ook allemaal mooi uitmeten'],
#   ['and so kapteyn thought:', 'en toen heeft kapteyn gedacht:'],
#   ['well, there must be useful work to be done also without a telescope',
#    'nou, er moeten toch ook allemaal nuttige dingen te doen zijn, ook als je geen kijker hebt'],
#   ['both astronomers got into contact about this idea and it quickly led to an agreement:',
#    'en daar is natuurlijk correspondentie over geweest'],
#   ['one can ask whether they realised the size of such an undertaking',
# ...
#    'dus, alles wat je nodig hebt om de volgende uren door te komen'],
#   ['a survival kit thank you', 'een overlevingspakket'],
#   ['saltine crackers, fruity lip balm',
#    'dank je wel crackers, fruitige lippenbalsem'],
#   ['who are you calling a fruity lip balm',
#    'wie noem jij een fruitige lippenbalsem'],
#   ['sour candies to absorb the toxicity',
#    'zure snoepjes om de giftigheid op te vangen'],
#   ['oh, gatorade', 'gatorade'],
#   ['sudoku', 'sudoku'],
#   ['our kids are almost identical', 'onze kinderen zijn bijna het zelfde'],
#   ['great minds think alike, huh', 'grote geesten denken hetzelfde, he'],
#   ["guess you don't need me at all",
#    'ik denk dat je me helemaal niet nodig hebt'],
#   ['no, sweetheart', 'nee, lieverd'],
#   ['you are exactly what i need', 'je bent precies wat ik nodig heb'],
#   ['thank you for this', 'dank je hiervoor'],
#   ['onwards to chemo', 'op naar chemo'],
#   ["if you're looking for the call room, you already passed it",
#    'als je de oproepkamer zoekt je bent er al voorbij'],
#   ['well, charlie harris', 'nou, charlie harris'],
#   ["how'd you know", 'hoe wist je dat'],
#   ['oh, same old bishop', 'dezelfde oude bishop'],
#   ['brilliant with a scalpel, lousy with directions',
#    'briljant met een scalpel, belabberd met een aanwijzingen'],
#   ['well, some things never change, like your handwriting',
#    'nou, sommige dingen veranderen nooit, zoals je handschrift'],
#   ['still chicken scratches', 'nog steeds hanenpoten'],
#   ["that's what makes me so popular with the staff",
#    'dat is wat me zo populair maakt bij het personeel'],
#   ['so, i guess the rumors about you joining us are true, then',
#    'dus, ik neem aan dat je geruchten dat je bij ons komt, waar zijn, dan'],
#   ['yeah, after training in l a', 'ja, na training in l a'],
#   ['got tired of bleach-blond nurses and gunshot wounds, huh',
#    'je had genoeg van bleekwaterblonde verpleegkundigen en schotwonden, he'],
#   ['never a dull moment', 'nooit een saai moment'],
#   ['no, not with you around', 'nee, niet met jou in de buurt'],
#   ['buckle up medics are coming in hot with two cirque performers who just fell 20 feet',
#    'riemen vast helpverleners komen binnen met twee circusartiesten die net 6 meter naar beneden vielen'],
#   ['illyana', 'illyana'],
#   ['uh, jeremy bishop', 'jeremy bishop'],
#   ["it's my first day", 'het is mijn eerste dag'],
#   ['zach miller', 'zach miller'],
#   ['so, what happened', 'dus wat is er gebeurd'],
#   ['he fell off a trapeze', 'viel hij uit de trapeze'],
#   ['kind of fitting for your first day',
#    'past wel een beetje bij je eerste dag'],
#   ["i'm more of a high wire myself",
#    'ik ben zelf meer een hoogspanningskabel'],
#   ['okay, on three', 'oke, op drie'],
#   ["all right, what's your name", 'oke, hoe heet je'],
#   ['but you have to help her', 'maar je moet haar helpen'],
#   ["his aerial partner's a minute out", 'zijn luchtpartner kom er zo aan'],
#   ['cirque de ciel, huh', 'cirque de ciel, he'],
#   ['i used to date a girl from the yorrick company',
#    'ik ging vroeger met een meisje van de yorrick company'],
#   ['she was a contortionist', 'ze was een slangenmens'],
#   ["yeah, you're right", 'ja je hebt gelijk'],
#   ["some things don't change", 'sommige dingen veranderen niet'],
#   ['illyana', 'illyana'],
#   ['relax, relax, relax', 'rustig, rustig, rustig'],
#   ['please, i need to see her', 'alsjeblieft, ik moet haar zien'],
#   ['just relax', 'ontspan'],
#   ['calm down for me, kurt, all right', 'kalmeer jezelf, kurt, oke'],
#   ['you guys got him', 'letten jullie op hem'],
#   ['okay, 1 milligram of ketamine for the pain',
#    'oke, 1 mg ketamine voor de pijn'],
#   ['okay, kurt', 'oke, kurt'],
#   ['hey, hey, kurt, kurt, look at me', 'he, he, kurt, kurt, kijk me aan'],
#   ['out of the way, please', 'aan de kant, alsjeblieft'],
#   ['i need you to focus, okay', 'je moet je concentreren, oke'],
#   ['can you wiggle your fingers for me',
#    'kun je met je vingers wiebelen voor me'],
#   ['now your toes', 'nu je tenen'],
#   ['okay, i need to reduce this hip', 'oke, ik moet deze heup zetten'],
#   ["all right, i'll stabilize", 'oke, ik zal stabiliseren'],
#   ['hey, bear with me, buddy', 'he, even volhouden, maat'],
#   ['that should give you enough torque', 'dat zou genoeg torsie moeten geven'],
#   ['okay, relax', 'oke, ontspan'],
#   ['relax your leg', 'ontspan je been'],
#   ["kurt, i'm gonna be putting your hip back in place",
#    'kurt, ik ga je heup terug op zijn plaats zetten'],
#   ["you're gonna feel some pain, followed by a pop, all right",
#    'je gaat wat pijn voelen gevolgd door een plop, oke'],
#   ['one, two, and three', 'een, twee en drie'],
#   ['and like a glove', 'en past precies'],
#   ['you should put on some doctory clothes',
#    'je moet je dokterskleding aandoen'],
#   ['greatest show on earth, right, charlie',
#    'grootste show op aarde, toch, charlie'],
#   ["spine's intact, but she's unresponsive",
#    'wervelkolom is intact, maar ze reageert niet'],
#   ["i'll have her tested for brain death",
#    'ik laat haar testen voor hersendood'],
#   ['s04e08 waiting on a friend', 'sync en nl-vertaling door janeliz'],
#   ["it's half past already", 'het is al half'],
#   ["i'm sorry", 'het spijt me'],
#   ['we got back late from the cottage', 'we kwamen laat terug uit het huisje'],
#   ['um, we were supposed to study before rounds',
#    'we hadden moeten studeren voor de rondes'],
#   ['i know, but it was so hard to leave',
#    'ik weet het, maar het was zo moeilijk om te vertrekken'],
#   ['it was beautiful there', 'het was prachtig daar'],
#   ['except for the mosquitoes they were huge', 'behalve de muggen'],
#   ['you should have seen the size of them',
#    'ze waren enorm je had moeten zien hoe groot ze waren'],
#   ['they were like vampire bats', 'zij waren als vampier vleermuizen'],
#   ['and for whatever reason, they were only biting me',
#    'en om wat voor reden dan ook, ze beten mij alleen'],
#   ["you should see my back i'm covered in bites",
#    'je zou mijn rug moeten zien'],
#   ["i can't stop scratching",
#    'ik sta onder de beten ik kan niet stoppen met krassen'],
#   ["except some of them, i can't really reach cause they're in the middle of my back",
#    'alleen bij sommige kan ik niet echt bij omdat ze midden op mijn rug zitten'],
#   ['would you mind rubbing this bite stuff on me oh',
#    'zou je het erg vinden om dit bijtspul op me te wrijven'],
#   ['who are you', 'oh wie ben jij'],
#   ["i'm a doctor", 'ik ben een dokter'],
#   ['so am i good', 'dat ben ik ook'],
#   ['so why are we yelling', 'goed waarom schreeuwen we dan'],
#   ['i', 'ik'],
#   ["i'm sorry, that's that's not possible",
#    'het het spijt me, dat is dat is niet mogelijk'],
#   ["she's gone i know", 'ze is heengegaan'],
#   ['inhales sharply but i', 'ik weet het maar ik ik zou bij haar moeten zijn'],
#   ["it's it's not fair that she's alone",
#    'het is het is niet eerlijk dat ze alleen is'],
#   ["right well, i'm", 'juist'],
#   ["i'm gonna make sure you have a chance to say a proper goodbye, all right",
#    'nou, ik ik ga ervoor zorgen dat je de kans krijgt om afscheid te nemen, oke'],
#   ['i just need you to lift up your arm for me',
#    'je moet je arm voor me optillen'],
#   ['kurt, did you know that illyana had agreed to be an organ donor',
#    'kurt, wist je dat illyana toegestemd had om een orgaandonor te zijn'],
#   ['we signed our cards together', 'ze ondertekenden onze kaarten samen'],
#   ["okay, well, of course, we're gonna need a final consent if there are any family members",
#    'oke, nou, natuurlijk, we moeten een definitieve toestemming hebben als er familieleden zijn'],
#   ["there aren't", 'die zijn er niet'],
#   ["i'm her only family", 'ik ben haar enige familie'],
#   ['well, illyana is gonna be able to help more people today than she ever could have imagined',
#    'nou, illyana gaat vandaag meer mensen kunnen helpen dat ze zich ooit had kunnen voorstellen'],
#   ['illyana is a match for a patient waiting for a kidney transplant',
#    'illyana is een match voor een patient die wacht op een niertransplantatie'],
#   ["that patient's fiance wanted to donate his, but they weren't a match",
#    'de verloofde van die patient wilde zijn nier doneren, maar ze waren geen match'],
#   ['but illyana is', 'maar illyana is dat wel'],
#   ["yeah, it's it's actually", 'ja, het is het is eigenlijk'],
#   ["it's even better than that", 'het is zelfs beter dan dat'],
#   ['we call all of this a domino transplant',
#    'we noemen dit een dominotransplantatie'],
#   ['seriously, are you are you hearing this', 'serieus, hoor je hoor je dit'],
#   ["it's nothing um okay, i'm", 'het is niets'],
#   ["i'm gonna be back in a bit to, uh to, um, put a proper cast on that",
#    'oke, ik ben ik ben zo terug om om een het juiste gips daar omheen te maken'],
#   ["so why don't you get some rest, okay", 'dus waarom rust je niet wat'],
#   ['shahir hm', 'shahir'],
#   ['second aerial performer female, 26, brain death',
#    'tweede trapezeartiest vrouw, 26, hersendood'],
#   ["she's on life support", 'ze wordt kunstmatig in leven gehouden'],
#   ["that's awful, alex", 'dat is vreselijk, alex'],
#   ["she's an organ donor", 'ze is orgaandonor'],
#   ["who's o-neg with a 6 antigen match",
#    'die o-negatief met een 6 antigeen match'],
#   ["shahir, she's the perfect donor for terry brown",
#    'shahir, ze is een perfecte donor voor terry brown'],
#   ["you're talking about the domino transplant",
#    'je hebt het over de dominotransplantatie'],
#   ["when's the last time you saved four lives in a single day",
#    'wanneer was de laatste keer dat je vier levens redde op een dag'],
#   ["we'll need to organize our surgeries so the wait time for each recipient is as soon as possible",
#    'we moeten onze operatie goed afstemmen zodat de wachttijd voor elke ontvanger zo snel mogelijk is'],
#   ["they'll need to be off of dialysis and ready to go as soon as their organs arrive",
#    'ze moeten van de dialyse af zijn en klaar om te gaan zodra hun organen komen'],
#   ['this is keith', 'dit is keith'],
#   ["he's our last recipient", 'hij is onze laatste ontvanger'],
#   ['this is all hands on deck', 'dit is alle hens aan dek'],
#   ["i'm gonna bring in the junior residents",
#    'ik ga de junior stagiaires er bij betrekken'],
#   ['williams and mirani will keep things moving',
#    'williams en mirani zorgen dat alles loopt'],
#   ["we'll get sekara to be our gopher for the day",
#    'we benoemen sekara als manusje van alles'],
#   ["the most important thing to remember is, we've got one shot at this",
#    'het meest belangrijke om te onthouden is, we hebben een kans hier'],
#   ['seven surgeries', 'zeven operaties'],
#   ["four harvest and three transplants in the next few hours before the final kidney goes to st donald's children's hospital",
#    'vier keer oogsten en drie transplantaties in de komen paar uur voordat de laatste nier naar kinderziekenhuis st'],
#   ['if something goes wrong with one',
#    'donald gaat als er iets mis gaat met een'],
#   ['and the dominoes stop falling, so no screw-ups',
#    "stoppen de domino's, dus geen miskleunen"],
#   ['everyone, dr jeremy bishop, our newest gen-surg on staff',
#    'iedereen, dr jeremy bishop, onze nieuwste algemeen chirurg'],
#   ["i'm alex reid", 'ik ben alex'],
#   ['yeah', 'reid ja'],
#   ['you need no introduction', 'je hebt geen introductie nodig'],
#   ["charlie's told me a lot about you",
#    'charlie heeft me veel over je verteld'],
#   ['thank you for diving in', 'dank je om in te springen'],
#   ['some of our junior residents', 'een paar van onze junior stagiaires'],
#   ['check the board, make sure you know where',
#    'kijk op het bord, zodat je weet waar'],
#   ['how are the bug bites', 'hoe is het met de muggenbeten'],
#   ["we'll be the first in the city to lead a multi-hospital domino transplant doogie",
#    'we zullen de eerste in de stad zijn die een multi-ziekenhuis domino transplantatie leiden'],
#   ["how's it going", 'he hoe gaat het'],
#   ['okay, maggie, take dev and start the first harvest',
#    'oke, maggie, neem dev mee en begin met de eerste oogst'],
#   ["cassie and asha, i'll need you to coordinate",
#    'cassie en asha, jullie moeten alles coordineren'],
#   ["i'll be handling all of the transplants",
#    'ik zal alle transplantaties onder mijn hoede nemen'],
#   ['dr bishop, want to do something fun today',
#    'dr bishop, wil je iets leuks doen vandaag'],
#   ['giddyup', 'kom maar op'],
#   ['everybody huddle in', 'iedereen samen'],
#   ['domino on three', "domino' op drie"],
#   ['domino', 'domino'],
#   ["i've always wanted to do that", 'dat heb ik altijd willen doen'],
#   ['dr kowalski, phone call on line 1', 'dr kowalski, telefoon op lijn 1'],
#   ['dr kowalski, line 1', 'dr kowalski, lijn 1'],
#   ['the magazine', 'het tijdschrift'],
#   ['uh, 2003', '2003'],
#   ['why would we want to read articles from so many years ago',
#    'waarom zouden we artekelen willen lezen van zo lang geleden'],
#   ["you know, we're cancer patients, not historians",
#    'weet je, we zijn kankerpatienten, geen historici'],
#   ['josh lewis, professor of 18th-century poetry',
#    'josh lewis, professor van de 18e eeuwse poezie'],
#   ['or, well, i was until', 'of, nou, dat was ik totdat'],
#   ['has the, uh, has the nurse been in yet no',
#    'is de verpleegster al geweest'],
#   ["it's hurry up and wait", 'nee, het is opschieten en wachten'],
#   ['well, they have to test our blood first, so',
#    'nou, ze moeten eerst ons bloed testen, dus'],
#   ["yeah, make sure it's okay to poison it",
#    'ja, om te zorgen dat het in orde is om het te vergiftigen'],
#   ["yeah, the irony's not lost on me but, then, nothing about this place makes any sense",
#    'ja, de ironie gaat niet verloren aan mij, maar, dan, niets hier is logisch'],
#   ["sorry didn't catch your name", 'sorry ik heb je naam niet gehoord'],
#   ['but most people around here call me dr kinney',
#    'maar de meeste mensen hier noemen me dr'],
#   ['dr kinney', 'dr kinney'],
#   ["what's the news, dawson", 'wat is het nieuws, dawson'],
#   ["you're good to go", 'je kunt beginnen'],
#   ["let's get you started on the docetaxel",
#    'laten we je aansluiten op docetaxel'],
#   ['yum, yum', 'jammie'],
#   ["i'm a doctor, too", 'ik ben ook een dokter'],
#   ['doctor of old poems', 'dokter van oude gedichten'],
#   ['you writing a book', 'schrijf je een boek'],
#   ['trying to', 'dat probeer ik'],
#   ['thought i might have at least one great novel in me',
#    'dacht dat ik tenminste een grote roman in mij had'],
#   ['although, now it turns out it might have to be a novella',
#    'hoewel, nu blijkt dat het misschien een novelle moet worden'],
#   ['or it might just be, you know, a professional hazard',
#    'of misschien is het, weet je, een professioneel risico'],
#   ['teaching all that great literature, making me think i can do it, too',
#    'al die grote literatuur onderwijzen, waardoor ik denk, dat ik het ook kan'],
#   ['speaking of professional hazards doctor becomes a patient, huh',
#    'nu we het over professioneel risico hebben dokter wordt een patient'],
#   ["you're next up, josh", 'je bent de volgende, josh'],
#   ["you guys need anything, i'm your gal today",
#    'als jullie iets nog hebben daar ben ik voor vandaag'],
#   ['thank you, dawson', 'dank je, dawson'],
#   ['you know, it must be hard, knowing all the facts, to still believe you can actually beat this',
#    'weet je, het moet moeilijk zijn, alle feiten kennen, en nog steeds te geloven dat je dit daadwerkelijk kunt verslaan'],
#   ["i'm putting both of you under at the same time",
#    'ik breng jullie beiden onder narcose op hetzelfde moment'],
#   ['no food, no drinks, so finish up your beers, boys',
#    'geen eten, geen dronken, dus drink je bier op, jongens'],
#   ['you ready to get off dialysis',
#    'ben je klaar om van de dialyse af te zijn'],
#   ["hell yeah, he's ready", 'ja zeker, hij is klaar'],
#   ['we got a wedding to plan', 'we moeten een bruiloft regelen'],
#   ["so, we got transport on standby to take your kidney to st donald's",
#    'dus, er staat vervoer klaar om te vertrekken om je nier naar st donald ziekenhuis te brengen'],
#   ['dr reid will be with you shortly', 'dr reid komt zo bij u'],
#   ...]]

# %%
def makeCorpus(pickle_off: str, pickle_to: str, corpus_num: int, limiter = -1, exists = False):
    input_stream = open(pickle_off, "rb")
    if exists: corpus = pickle.load(open(pickle_to, "rb"))
    else: corpus = set()
    while limiter != 0:
        try:
            data = pickle.load(input_stream)
            for row in data:
                for word in row[corpus_num].split():
                    corpus.add(word)
            print("Chunk processed.")
            limiter -= 1
        except EOFError:
            break
    input_stream.close()
    output_stream = open(pickle_to, "wb")
    pickle.dump(corpus, output_stream)
    output_stream.close()

# %%
makeCorpus("data/sample_shorty.pkl", "data/en_shorty.pkl", 0, limiter = 8)
print("Second Corpus Started")
makeCorpus("data/sample_shorty.pkl", "data/nl_shorty.pkl", 1, limiter = 8)
# Out:
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Second Corpus Started
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.
# Chunk processed.

# %%
a = pickle.load(open("data/en_shorty.pkl", "rb"))
b = pickle.load(open("data/nl_shorty.pkl", "rb"))
print(len(a))
print(len(b))
# Out:
# 1926
# 1840
